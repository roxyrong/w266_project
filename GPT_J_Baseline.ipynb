# %% [markdown]
# <a href="https://colab.research.google.com/github/roxyrong/w266_project/blob/main/GPT_J_Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Experiment 1: Baseline GPT-J 6B parameter model
#
# The goal of this notebook is to construct a prompt design which reliably returns SQL code to test the pretrained text-to-SQL performance of the [GPT-J 6B parameter transformer model](https://huggingface.co/EleutherAI/gpt-j-6b).

# %% [markdown]
# ## Notebook & Environment Setup

# %%
# Install non-natively available libraries
# %%capture

#!pip install transformers
# !pip install sentencepiece
# !pip install accelerate -U
# !pip install datasets
# !pip install nltk

# Install required libraries for 8-bit runtime
# !pip install --quiet bitsandbytes
# !pip install --quiet git+https://github.com/huggingface/transformers.git # Install latest version of transformers
# !pip install --quiet accelerate

# %%
# Imports
import os
import sys
from typing import Dict, List
import subprocess
import collections
import json
import random
import numpy as np
import pandas as pd
import nltk
import torch
import pprint
from google.colab import drive


# Import GPT-J for text generation + AutoTokenizer
from transformers import GPTJForCausalLM, AutoTokenizer

# for evaluation
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Set up Google Drive for data storage

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/w266_project


project_path = '/content/drive/MyDrive/Github/w266_project'
sys.path.append(project_path)
# Out:
# /content/drive/MyDrive/Github/w266_project

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Github/w266_project'

# %%
# setup third_party drive with spider dataset and utilities, only need to do once
# %mkdir third_party
# %cd third_party
# !git clone https://github.com/taoyds/spider.git
# !git clone https://github.com/HKUNLP/UnifiedSKG.git

# %% [markdown]
# ## Spider Data Set Structure Exploration

# %%
# Load Spider datasets
with open('spider/train_spider.json', 'r') as f:
    train_spider = pd.read_json(f)
with open('spider/train_others.json', 'r') as f:
    others_spider = pd.read_json(f)
with open('spider/dev.json', 'r') as f:
    dev_spider = pd.read_json(f)

# %%
train_spider.head()
# Out:
#                    db_id                                              query  \
# 0  department_management         SELECT count(*) FROM head WHERE age  >  56
# 1  department_management  SELECT name ,  born_state ,  age FROM head ORD...
# 2  department_management  SELECT creation ,  name ,  budget_in_billions ...
# 3  department_management  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  department_management  SELECT avg(num_employees) FROM department WHER...
#
#                                           query_toks  \
# 0  [SELECT, count, (, *, ), FROM, head, WHERE, ag...
# 1  [SELECT, name, ,, born_state, ,, age, FROM, he...
# 2  [SELECT, creation, ,, name, ,, budget_in_billi...
# 3  [SELECT, max, (, budget_in_billions, ), ,, min...
# 4  [SELECT, avg, (, num_employees, ), FROM, depar...
#
#                                  query_toks_no_value  \
# 0  [select, count, (, *, ), from, head, where, ag...
# 1  [select, name, ,, born_state, ,, age, from, he...
# 2  [select, creation, ,, name, ,, budget_in_billi...
# 3  [select, max, (, budget_in_billions, ), ,, min...
# 4  [select, avg, (, num_employees, ), from, depar...
#
#                                             question  \
# 0  How many heads of the departments are older th...
# 1  List the name, born state and age of the heads...
# 2  List the creation year, name and budget of eac...
# 3  What are the maximum and minimum budget of the...
# 4  What is the average number of employees of the...
#
#                                        question_toks  \
# 0  [How, many, heads, of, the, departments, are, ...
# 1  [List, the, name, ,, born, state, and, age, of...
# 2  [List, the, creation, year, ,, name, and, budg...
# 3  [What, are, the, maximum, and, minimum, budget...
# 4  [What, is, the, average, number, of, employees...
#
#                                                  sql
# 0  {'from': {'table_units': [['table_unit', 1]], ...
# 1  {'from': {'table_units': [['table_unit', 1]], ...
# 2  {'from': {'table_units': [['table_unit', 0]], ...
# 3  {'from': {'table_units': [['table_unit', 0]], ...
# 4  {'from': {'table_units': [['table_unit', 0]], ...

# %%
# show first 5 elements of training set
# for i in range(0, 4):
#   print(train_spider.iloc[i])
#   print(train_spider.iloc[i]['question'])
#   print(train_spider.iloc[i]['query'])

# Show 5 random elements of training set db_id, question, query
sample = train_spider.sample(n=5)
for i in range(0,5):
  print(sample.iloc[i]['db_id'])
  print(sample.iloc[i]['question'])
  print(sample.iloc[i]['query'])
  print('\n')
# Out:
# match_season
# Who are the players from Indonesia?
# SELECT T2.Player FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Country_name  =  "Indonesia"
#
#
# department_store
# What is the id and name of the staff who has been assigned for the least amount of time?
# SELECT T1.staff_id ,  T1.staff_name FROM staff AS T1 JOIN Staff_Department_Assignments AS T2 ON T1.staff_id  =  T2.staff_id ORDER BY date_assigned_to - date_assigned_from LIMIT 1
#
#
# tracking_grants_for_research
# List the project details of the project both producing patent and paper as outcomes.
# SELECT T1.project_details FROM Projects AS T1 JOIN Project_outcomes AS T2 ON T1.project_id  =  T2.project_id WHERE T2.outcome_code  =  'Paper' INTERSECT SELECT T1.project_details FROM Projects AS T1 JOIN Project_outcomes AS T2 ON T1.project_id  =  T2.project_id WHERE T2.outcome_code  =  'Patent'
#
#
# voter_2
# Find the distinct last names of all the students who have president votes and whose advisor is not 2192.
# SELECT DISTINCT T1.LName FROM STUDENT AS T1 JOIN VOTING_RECORD AS T2 ON T1.StuID  =  PRESIDENT_Vote EXCEPT SELECT DISTINCT LName FROM STUDENT WHERE Advisor  =  "2192"
#
#
# workshop_paper
# Which authors have submitted to more than one workshop?
# SELECT T2.Author FROM acceptance AS T1 JOIN submission AS T2 ON T1.Submission_ID  =  T2.Submission_ID GROUP BY T2.Author HAVING COUNT(DISTINCT T1.workshop_id)  >  1

# %%
# Load schema for all tables
with open('spider/tables.json', 'r') as f:
    schema_df = pd.read_json(f)

# %%
# Helper Function to extract target schemas from Spider json to a dict
# for training and prompt usage.
def _get_schema_string(table_json):
    """Returns the schema serialized as a string."""
    table_id_to_column_names = collections.defaultdict(list)
    for table_id, name in table_json["column_names_original"]:
        table_id_to_column_names[table_id].append(name.lower())
        tables = table_json["table_names_original"]

    table_strings = []
    for table_id, table_name in enumerate(tables):
        column_names = table_id_to_column_names[table_id]
        table_string = " | %s : %s" % (table_name.lower(), " , ".join(column_names))
        table_strings.append(table_string)

    return "".join(table_strings)

schema_dict = {}
for idx, row in schema_df.iterrows():
    db_id = row['db_id']
    schema = _get_schema_string(row)
    schema_dict[db_id] = schema

# %%
print(schema_dict.keys())
# Out:
# dict_keys(['perpetrator', 'college_2', 'flight_company', 'icfp_1', 'body_builder', 'storm_record', 'pilot_record', 'race_track', 'academic', 'department_store', 'music_4', 'insurance_fnol', 'cinema', 'decoration_competition', 'phone_market', 'store_product', 'assets_maintenance', 'student_assessment', 'dog_kennels', 'music_1', 'company_employee', 'farm', 'solvency_ii', 'city_record', 'swimming', 'flight_2', 'election', 'manufactory_1', 'debate', 'network_2', 'local_govt_in_alabama', 'climbing', 'e_learning', 'scientist_1', 'ship_1', 'entertainment_awards', 'allergy_1', 'imdb', 'products_for_hire', 'candidate_poll', 'chinook_1', 'flight_4', 'pets_1', 'dorm_1', 'journal_committee', 'flight_1', 'medicine_enzyme_interaction', 'local_govt_and_lot', 'station_weather', 'shop_membership', 'driving_school', 'concert_singer', 'music_2', 'sports_competition', 'railway', 'inn_1', 'museum_visit', 'browser_web', 'baseball_1', 'architecture', 'csu_1', 'tracking_orders', 'insurance_policies', 'gas_company', 'e_government', 'school_bus', 'machine_repair', 'theme_gallery', 'film_rank', 'party_people', 'hospital_1', 'customers_campaigns_ecommerce', 'gymnast', 'restaurants', 'mountain_photos', 'battle_death', 'cre_Doc_Control_Systems', 'tracking_share_transactions', 'apartment_rentals', 'student_transcripts_tracking', 'cre_Docs_and_Epenses', 'ship_mission', 'company_office', 'tracking_software_problems', 'products_gen_characteristics', 'coffee_shop', 'riding_club', 'customers_card_transactions', 'county_public_safety', 'performance_attendance', 'club_1', 'singer', 'culture_company', 'cre_Doc_Template_Mgt', 'musical', 'world_1', 'device', 'tracking_grants_for_research', 'employee_hire_evaluation', 'movie_1', 'network_1', 'poker_player', 'program_share', 'aircraft', 'restaurant_1', 'customers_and_invoices', 'insurance_and_eClaims', 'college_1', 'local_govt_mdm', 'book_2', 'hr_1', 'soccer_1', 'sakila_1', 'real_estate_properties', 'college_3', 'course_teach', 'roller_coaster', 'customer_deliveries', 'game_injury', 'school_finance', 'scholar', 'voter_1', 'match_season', 'small_bank_1', 'wta_1', 'yelp', 'student_1', 'manufacturer', 'store_1', 'train_station', 'document_management', 'formula_1', 'game_1', 'loan_1', 'bike_1', 'entrepreneur', 'orchestra', 'cre_Drama_Workshop_Groups', 'car_1', 'geo', 'behavior_monitoring', 'cre_Doc_Tracking_DB', 'university_basketball', 'soccer_2', 'activity_1', 'cre_Theme_park', 'twitter_1', 'election_representative', 'voter_2', 'wedding', 'news_report', 'wine_1', 'customers_and_addresses', 'protein_institute', 'school_player', 'phone_1', 'tvshow', 'wrestler', 'customer_complaints', 'department_management', 'customers_and_products_contacts', 'company_1', 'workshop_paper', 'epinions_1', 'party_host', 'product_catalog'])

# %%
print(schema_dict['cre_Doc_Control_Systems'], '\n')
print(schema_dict['shop_membership'], '\n')
print(schema_dict['bike_1'], '\n')
print(schema_dict['cre_Doc_Tracking_DB'], '\n')
print(schema_dict['twitter_1'], '\n')
print(schema_dict['journal_committee'], '\n')
# Out:
#  | ref_document_types : document_type_code , document_type_description | roles : role_code , role_description | addresses : address_id , address_details | ref_document_status : document_status_code , document_status_description | ref_shipping_agents : shipping_agent_code , shipping_agent_name , shipping_agent_description | documents : document_id , document_status_code , document_type_code , shipping_agent_code , receipt_date , receipt_number , other_details | employees : employee_id , role_code , employee_name , other_details | document_drafts : document_id , draft_number , draft_details | draft_copies : document_id , draft_number , copy_number | circulation_history : document_id , draft_number , copy_number , employee_id | documents_mailed : document_id , mailed_to_address_id , mailing_date
#
#  | member : member_id , card_number , name , hometown , level | branch : branch_id , name , open_year , address_road , city , membership_amount | membership_register_branch : member_id , branch_id , register_year | purchase : member_id , branch_id , year , total_pounds
#
#  | station : id , name , lat , long , dock_count , city , installation_date | status : station_id , bikes_available , docks_available , time | trip : id , duration , start_date , start_station_name , start_station_id , end_date , end_station_name , end_station_id , bike_id , subscription_type , zip_code | weather : date , max_temperature_f , mean_temperature_f , min_temperature_f , max_dew_point_f , mean_dew_point_f , min_dew_point_f , max_humidity , mean_humidity , min_humidity , max_sea_level_pressure_inches , mean_sea_level_pressure_inches , min_sea_level_pressure_inches , max_visibility_miles , mean_visibility_miles , min_visibility_miles , max_wind_speed_mph , mean_wind_speed_mph , max_gust_speed_mph , precipitation_inches , cloud_cover , events , wind_dir_degrees , zip_code
#
#  | ref_document_types : document_type_code , document_type_name , document_type_description | ref_calendar : calendar_date , day_number | ref_locations : location_code , location_name , location_description | roles : role_code , role_name , role_description | all_documents : document_id , date_stored , document_type_code , document_name , document_description , other_details | employees : employee_id , role_code , employee_name , gender_mfu , date_of_birth , other_details | document_locations : document_id , location_code , date_in_location_from , date_in_locaton_to | documents_to_be_destroyed : document_id , destruction_authorised_by_employee_id , destroyed_by_employee_id , planned_destruction_date , actual_destruction_date , other_details
#
#  | follows : f1 , f2 | tweets : id , uid , text , createdate | user_profiles : uid , name , email , partitionid , followers
#
#  | journal : journal_id , date , theme , sales | editor : editor_id , name , age | journal_committee : editor_id , journal_id , work_type

# %% [markdown]
# A few examples from Spider to help with the prompt model:
#
# Schema string:
#
#  | department : department_id , name , creation , ranking , budget_in_billions , num_employees | head : head_id , name , born_state , age | management : department_id , head_id , temporary_acting
#
#  Question:
#
#  How many heads of the departments are older than 56 ?
#
#  Query:
#
#  SELECT count(*) FROM head WHERE age  >  56
#
#  ____
# flight_4
#
# What is the name, city, and country of the airport with the lowest altitude?
# SELECT name ,  city ,  country FROM airports ORDER BY elevation LIMIT 1
#
#
# aircraft
#
# what is the name and age of the youngest winning pilot?
# SELECT t1.name ,  t1.age FROM pilot AS t1 JOIN MATCH AS t2 ON t1.pilot_id  =  t2.winning_pilot ORDER BY t1.age LIMIT 1
#
#
# icfp_1
#
# How many papers are "Atsushi Ohori" the author of?
# SELECT count(*) FROM authors AS t1 JOIN authorship AS t2 ON t1.authid  =  t2.authid JOIN papers AS t3 ON t2.paperid  =  t3.paperid WHERE  t1.fname  =  "Atsushi" AND t1.lname  =  "Ohori"
#
#
# activity_1
#
# How many faculty members participate in each activity? Return the activity names and the number of faculty members.
# SELECT T1.activity_name ,  count(*) FROM Activity AS T1 JOIN Faculty_participates_in AS T2 ON T1.actID  =  T2.actID GROUP BY T1.actID
#
# journal_committee
#
# Show the names of editors of age either 24 or 25.
# SELECT Name FROM editor WHERE Age  =  24 OR Age  =  25

# %% [markdown]
# ## Set up and load stock pretrained float 16 GPT-J model

# %%
# # Specify GPU for computations
# device = "cuda"

# # Load pretrained float16 GPT-J to GPU from Huggingface
# # model = GPTJForCausalLM.from_pretrained(
# #     "EleutherAI/gpt-j-6B",
# #     revision="float16",
# #     torch_dtype=torch.float16,
# # ).to(device)

# # Load pretrained float16 GPT-J from Google Drive
# model = GPTJForCausalLM.from_pretrained(
#     "pretrained_GPT-J",
# ).to(device)

# %%
#Save model to Google Drive to avoid long download times - only needed when needed :-)
# model.save_pretrained("pretrained_GPT-J", from_pt=True)

# %% [markdown]
# ## Load tokenizer

# %%
# # Load appropriate tokenizer for model
# tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B", padding_side="left")

# %% [markdown]
# ## Set up an 8-bit version
#
# Memory runs out with stock version for batch inference, so fine tuning is going to be tough.
#
# [Huggingface page for gpt-j-6B-8bit](https://huggingface.co/hivemind/gpt-j-6B-8bit)
#
# [source notebook](https://colab.research.google.com/drive/1ft6wQU0BhqG5PRlwgaZJv2VukKKjU4Es#scrollTo=p0dy1ZFwClcq)

# %%
import transformers

import torch
import torch.nn.functional as F
from torch import nn
from torch.cuda.amp import custom_fwd, custom_bwd

from bitsandbytes.functional import quantize_blockwise, dequantize_blockwise

from tqdm.auto import tqdm

# %%
class FrozenBNBLinear(nn.Module):
    def __init__(self, weight, absmax, code, bias=None):
        assert isinstance(bias, nn.Parameter) or bias is None
        super().__init__()
        self.out_features, self.in_features = weight.shape
        self.register_buffer("weight", weight.requires_grad_(False))
        self.register_buffer("absmax", absmax.requires_grad_(False))
        self.register_buffer("code", code.requires_grad_(False))
        self.adapter = None
        self.bias = bias

    def forward(self, input):
        output = DequantizeAndLinear.apply(input, self.weight, self.absmax, self.code, self.bias)
        if self.adapter:
            output += self.adapter(input)
        return output

    @classmethod
    def from_linear(cls, linear: nn.Linear) -> "FrozenBNBLinear":
        weights_int8, state = quantize_blockise_lowmemory(linear.weight)
        return cls(weights_int8, *state, linear.bias)

    def __repr__(self):
        return f"{self.__class__.__name__}({self.in_features}, {self.out_features})"


class DequantizeAndLinear(torch.autograd.Function):
    @staticmethod
    @custom_fwd
    def forward(ctx, input: torch.Tensor, weights_quantized: torch.ByteTensor,
                absmax: torch.FloatTensor, code: torch.FloatTensor, bias: torch.FloatTensor):
        weights_deq = dequantize_blockwise(weights_quantized, absmax=absmax, code=code)
        ctx.save_for_backward(input, weights_quantized, absmax, code)
        ctx._has_bias = bias is not None
        return F.linear(input, weights_deq, bias)

    @staticmethod
    @custom_bwd
    def backward(ctx, grad_output: torch.Tensor):
        assert not ctx.needs_input_grad[1] and not ctx.needs_input_grad[2] and not ctx.needs_input_grad[3]
        input, weights_quantized, absmax, code = ctx.saved_tensors
        # grad_output: [*batch, out_features]
        weights_deq = dequantize_blockwise(weights_quantized, absmax=absmax, code=code)
        grad_input = grad_output @ weights_deq
        grad_bias = grad_output.flatten(0, -2).sum(dim=0) if ctx._has_bias else None
        return grad_input, None, None, None, grad_bias


class FrozenBNBEmbedding(nn.Module):
    def __init__(self, weight, absmax, code):
        super().__init__()
        self.num_embeddings, self.embedding_dim = weight.shape
        self.register_buffer("weight", weight.requires_grad_(False))
        self.register_buffer("absmax", absmax.requires_grad_(False))
        self.register_buffer("code", code.requires_grad_(False))
        self.adapter = None

    def forward(self, input, **kwargs):
        with torch.no_grad():
            # note: both quantuized weights and input indices are *not* differentiable
            weight_deq = dequantize_blockwise(self.weight, absmax=self.absmax, code=self.code)
            output = F.embedding(input, weight_deq, **kwargs)
        if self.adapter:
            output += self.adapter(input)
        return output

    @classmethod
    def from_embedding(cls, embedding: nn.Embedding) -> "FrozenBNBEmbedding":
        weights_int8, state = quantize_blockise_lowmemory(embedding.weight)
        return cls(weights_int8, *state)

    def __repr__(self):
        return f"{self.__class__.__name__}({self.num_embeddings}, {self.embedding_dim})"


def quantize_blockise_lowmemory(matrix: torch.Tensor, chunk_size: int = 2 ** 20):
    assert chunk_size % 4096 == 0
    code = None
    chunks = []
    absmaxes = []
    flat_tensor = matrix.view(-1)
    for i in range((matrix.numel() - 1) // chunk_size + 1):
        input_chunk = flat_tensor[i * chunk_size: (i + 1) * chunk_size].clone()
        quantized_chunk, (absmax_chunk, code) = quantize_blockwise(input_chunk, code=code)
        chunks.append(quantized_chunk)
        absmaxes.append(absmax_chunk)

    matrix_i8 = torch.cat(chunks).reshape_as(matrix)
    absmax = torch.cat(absmaxes)
    return matrix_i8, (absmax, code)


def convert_to_int8(model):
    """Convert linear and embedding modules to 8-bit with optional adapters"""
    for module in list(model.modules()):
        for name, child in module.named_children():
            if isinstance(child, nn.Linear):
                print(name, child)
                setattr(
                    module,
                    name,
                    FrozenBNBLinear(
                        weight=torch.zeros(child.out_features, child.in_features, dtype=torch.uint8),
                        absmax=torch.zeros((child.weight.numel() - 1) // 4096 + 1),
                        code=torch.zeros(256),
                        bias=child.bias,
                    ),
                )
            elif isinstance(child, nn.Embedding):
                setattr(
                    module,
                    name,
                    FrozenBNBEmbedding(
                        weight=torch.zeros(child.num_embeddings, child.embedding_dim, dtype=torch.uint8),
                        absmax=torch.zeros((child.weight.numel() - 1) // 4096 + 1),
                        code=torch.zeros(256),
                    )
                )

# %%
class GPTJBlock(transformers.models.gptj.modeling_gptj.GPTJBlock):
    def __init__(self, config):
        super().__init__(config)

        convert_to_int8(self.attn)
        convert_to_int8(self.mlp)


class GPTJModel(transformers.models.gptj.modeling_gptj.GPTJModel):
    def __init__(self, config):
        super().__init__(config)
        convert_to_int8(self)


class GPTJForCausalLM(transformers.models.gptj.modeling_gptj.GPTJForCausalLM):
    def __init__(self, config):
        super().__init__(config)
        convert_to_int8(self)


transformers.models.gptj.modeling_gptj.GPTJBlock = GPTJBlock  # monkey-patch GPT-J

# %%
config = transformers.GPTJConfig.from_pretrained("EleutherAI/gpt-j-6B")
tokenizer = transformers.AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B", padding_side="left")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/930 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/4.04k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]

# %%
model = GPTJForCausalLM.from_pretrained("hivemind/gpt-j-6B-8bit", low_cpu_mem_usage=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/6.18G [00:00<?, ?B/s]
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# k_proj Linear(in_features=4096, out_features=4096, bias=False)
# v_proj Linear(in_features=4096, out_features=4096, bias=False)
# q_proj Linear(in_features=4096, out_features=4096, bias=False)
# out_proj Linear(in_features=4096, out_features=4096, bias=False)
# fc_in Linear(in_features=4096, out_features=16384, bias=True)
# fc_out Linear(in_features=16384, out_features=4096, bias=True)
# lm_head Linear(in_features=4096, out_features=50400, bias=True)
# GPTJForCausalLM(
#   (transformer): GPTJModel(
#     (wte): FrozenBNBEmbedding(50400, 4096)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0-27): 28 x GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): FrozenBNBLinear(4096, 4096)
#           (v_proj): FrozenBNBLinear(4096, 4096)
#           (q_proj): FrozenBNBLinear(4096, 4096)
#           (out_proj): FrozenBNBLinear(4096, 4096)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): FrozenBNBLinear(4096, 16384)
#           (fc_out): FrozenBNBLinear(16384, 4096)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): FrozenBNBLinear(4096, 50400)
# )

# %% [markdown]
# ## Experimentation to build a workable prompt

# %%
# Test prompt
prompt = ("\n-- Parse the question into SQL based on the given table below.--\n\n"
          " | routes : rid , dst_apid , dst_ap , src_apid , src_ap , alid , airline , codeshare | airports : apid , name , city , country , x , y , elevation , iata , icao | airlines : alid , name , iata , icao , callsign , country , active"
          "\n Based on this schema, create an ANSI-92 SQL Query to answer the following question:\n"
          "Q:What is the name, city, and country of the airport with the lowest altitude?"
          "\n Return the SQL query ONLY. Do not include any additional explanation."
          )
#prompt = ("# Question: What is the name, city, and country of the airport with the lowest altitude?"
          # "# Schema: | routes : rid , dst_apid , dst_ap , src_apid , src_ap , alid , airline , codeshare | airports : apid , name , city , country , x , y , elevation , iata , icao | airlines : alid , name , iata , icao , callsign , country , active"
          # "SQL Query:")

# Tokenize prompt, load to GPU with model
input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

# Generate response tokens from GPT-J
gen_tokens = model.generate(
    input_ids,
    do_sample=True,
    temperature=0.1,
    max_new_tokens=128,
    repetition_penalty=1.1,
    top_p=1,
)

# Retrieve and print response
gen_text = tokenizer.batch_decode(gen_tokens)[0]

print(gen_text)

# import re

# s = gen_text

# # Use re.findall to get all matches
# matches = re.search(r"(SELECT.*?;)", s, re.DOTALL)

# if match:
#     print("Query only: \n", match)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# -- Parse the question into SQL based on the given table below.--
#
#  | routes : rid, dst_apid, dst_ap, src_apid, src_ap, alid, airline, codeshare | airports : apid, name, city, country, x, y, elevation, iata, icao | airlines : alid, name, iata, icao, callsign, country, active
#  Based on this schema, create an ANSI-92 SQL Query to answer the following question:
# Q:What is the name, city, and country of the airport with the lowest altitude?
#  Return the SQL query ONLY. Do not include any additional explanation.
#
# A:
#
# This should work for you:
# SELECT a.* FROM airports AS a
# INNER JOIN (
#   SELECT alid, MIN(elevation) AS minElevation
#   FROM airports
#   GROUP BY alid
# ) AS b ON a.alid = b.alid AND a.elevation = b.minElevation;
#
# SQL Fiddle Demo
#
# <|endoftext|>

# %%
# Load appropriate tokenizer for model
tokenizer = transformers.AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B", padding_side="left")

# Test prompt
prompt = ("\n-- Parse the question into SQL based on the given table below.--\n\n"
          "| department : department_id , name , creation , ranking , budget_in_billions , num_employees | head : head_id , name , born_state , age | management : department_id , head_id , temporary_acting"
          "\n Based on this schema, create an ANSI-92 SQL Query to answer the following question:\n"
          "Q:How many heads of the departments are older than 56 ?"
          "\n As answer, return the SQL query ONLY. Do not include any additional explanation."
          )

# Tokenize prompt, load to GPU with model
input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

# Generate response tokens from GPT-J
gen_tokens = model.generate(
    input_ids,
    do_sample=True,
    temperature=0.1,
    max_new_tokens=128,
    repetition_penalty=1.1,
    top_p=1,
)

# Retrieve and print response
gen_text = tokenizer.batch_decode(gen_tokens)[0]

print(gen_text)

# import re

# s = gen_text

# # Use re.findall to extract the first query
# matches = re.search(r"(SELECT.*?;)", s, re.DOTALL)

# if match:
#     print("Query only: \n", match)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# -- Parse the question into SQL based on the given table below.--
#
# | department : department_id, name, creation, ranking, budget_in_billions, num_employees | head : head_id, name, born_state, age | management : department_id, head_id, temporary_acting
#  Based on this schema, create an ANSI-92 SQL Query to answer the following question:
# Q:How many heads of the departments are older than 56?
#  As answer, return the SQL query ONLY. Do not include any additional explanation.
#
# A:
#
# This is a simple example of how you can use the "with" clause in PostgreSQL.  The basic idea is that you want to select all rows from the table and then filter them using the where clause.  In your case, you want to select all rows from the table and then filter them by the column "age".  You can do this with the "where" clause.  Here's an example:
# select * from employees
# where age > 56;
#
# <|endoftext|>

# %%
# Try few shot training
# Load appropriate tokenizer for model (not good to repeat here?)
tokenizer = transformers.AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B", padding_side="left")

# cre_Doc_Control_Systems
# Which employee has showed up in most circulation history documents. List the employee's name and the number of drafts and copies.
# SELECT Employees.employee_name , count(*) FROM Employees JOIN Circulation_History ON Circulation_History.employee_id = Employees.employee_id GROUP BY Circulation_History.document_id , Circulation_History.draft_number , Circulation_History.copy_number ORDER BY count(*) DESC LIMIT 1;
# | ref_document_types : document_type_code , document_type_description | roles : role_code , role_description | addresses : address_id , address_details | ref_document_status : document_status_code , document_status_description | ref_shipping_agents : shipping_agent_code , shipping_agent_name , shipping_agent_description | documents : document_id , document_status_code , document_type_code , shipping_agent_code , receipt_date , receipt_number , other_details | employees : employee_id , role_code , employee_name , other_details | document_drafts : document_id , draft_number , draft_details | draft_copies : document_id , draft_number , copy_number | circulation_history : document_id , draft_number , copy_number , employee_id | documents_mailed : document_id , mailed_to_address_id , mailing_date


# shop_membership
# What are names for top three branches with most number of membership?
# SELECT name FROM branch ORDER BY membership_amount DESC LIMIT 3
# | member : member_id , card_number , name , hometown , level | branch : branch_id , name , open_year , address_road , city , membership_amount | membership_register_branch : member_id , branch_id , register_year | purchase : member_id , branch_id , year , total_pounds


# bike_1
# What is the id of the trip that has the shortest duration?
# SELECT id FROM trip ORDER BY duration LIMIT 1
# | station : id , name , lat , long , dock_count , city , installation_date | status : station_id , bikes_available , docks_available , time | trip : id , duration , start_date , start_station_name , start_station_id , end_date , end_station_name , end_station_id , bike_id , subscription_type , zip_code | weather : date , max_temperature_f , mean_temperature_f , min_temperature_f , max_dew_point_f , mean_dew_point_f , min_dew_point_f , max_humidity , mean_humidity , min_humidity , max_sea_level_pressure_inches , mean_sea_level_pressure_inches , min_sea_level_pressure_inches , max_visibility_miles , mean_visibility_miles , min_visibility_miles , max_wind_speed_mph , mean_wind_speed_mph , max_gust_speed_mph , precipitation_inches , cloud_cover , events , wind_dir_degrees , zip_code


# cre_Doc_Tracking_DB
# What are all the document type codes and document type names?
# SELECT document_type_code ,  document_type_name FROM Ref_document_types
# | ref_document_types : document_type_code , document_type_name , document_type_description | ref_calendar : calendar_date , day_number | ref_locations : location_code , location_name , location_description | roles : role_code , role_name , role_description | all_documents : document_id , date_stored , document_type_code , document_name , document_description , other_details | employees : employee_id , role_code , employee_name , gender_mfu , date_of_birth , other_details | document_locations : document_id , location_code , date_in_location_from , date_in_locaton_to | documents_to_be_destroyed : document_id , destruction_authorised_by_employee_id , destroyed_by_employee_id , planned_destruction_date , actual_destruction_date , other_details


# twitter_1
# Find the average number of followers for the users who do not have any tweet.
# SELECT avg(followers) FROM user_profiles WHERE UID NOT IN (SELECT UID FROM tweets)
# )
# | follows : f1 , f2 | tweets : id , uid , text , createdate | user_profiles : uid , name , email , partitionid , followers

          #  ###
          #  Context: | station : id , name , lat , long , dock_count , city , installation_date | status : station_id , bikes_available , docks_available , time | trip : id , duration , start_date , start_station_name , start_station_id , end_date , end_station_name , end_station_id , bike_id , subscription_type , zip_code | weather : date , max_temperature_f , mean_temperature_f , min_temperature_f , max_dew_point_f , mean_dew_point_f , min_dew_point_f , max_humidity , mean_humidity , min_humidity , max_sea_level_pressure_inches , mean_sea_level_pressure_inches , min_sea_level_pressure_inches , max_visibility_miles , mean_visibility_miles , min_visibility_miles , max_wind_speed_mph , mean_wind_speed_mph , max_gust_speed_mph , precipitation_inches , cloud_cover , events , wind_dir_degrees , zip_code
          #  Question:What is the id of the trip that has the shortest duration?
          #  Answer: SELECT id FROM trip ORDER BY duration LIMIT 1
          #  ###
          #  Context: | follows : f1 , f2 | tweets : id , uid , text , createdate | user_profiles : uid , name , email , partitionid , followers
          #  Question: What are all the document type codes and document type names?
          #  Answer: SELECT document_type_code ,  document_type_name FROM Ref_document_types


prompt = ("""Context: | ref_document_types : document_type_code , document_type_description | roles : role_code , role_description | addresses : address_id , address_details | ref_document_status : document_status_code , document_status_description | ref_shipping_agents : shipping_agent_code , shipping_agent_name , shipping_agent_description | documents : document_id , document_status_code , document_type_code , shipping_agent_code , receipt_date , receipt_number , other_details | employees : employee_id , role_code , employee_name , other_details | document_drafts : document_id , draft_number , draft_details | draft_copies : document_id , draft_number , copy_number | circulation_history : document_id , draft_number , copy_number , employee_id | documents_mailed : document_id , mailed_to_address_id , mailing_date
           Question: Which employee has showed up in most circulation history documents. List the employee's name and the number of drafts and copies.\n"
           Answer: SELECT Employees.employee_name , count(*) FROM Employees JOIN Circulation_History ON Circulation_History.employee_id = Employees.employee_id GROUP BY Circulation_History.document_id , Circulation_History.draft_number , Circulation_History.copy_number ORDER BY count(*) DESC LIMIT 1;
           ###
           Context:| member : member_id , card_number , name , hometown , level | branch : branch_id , name , open_year , address_road , city , membership_amount | membership_register_branch : member_id , branch_id , register_year | purchase : member_id , branch_id , year , total_pounds
           Question: What are names for top three branches with most number of membership?
           Answer: SELECT name FROM branch ORDER BY membership_amount DESC LIMIT 3
           ###
           Context: | department : department_id , name , creation , ranking , budget_in_billions , num_employees | head : head_id , name , born_state , age | management : department_id , head_id , temporary_acting
           Question: How many heads of the departments are older than 56?
           Answer: """

)

# prompt = ("""[Text]: Helena Smith founded Core.ai 2 years ago. She is now the CEO and CTO of the company and is building a team of highly skilled developers in machine learning and natural language processing.
#         [Position]: CEO and CTO
#         ###
#         [Text]: Tech Robotics is a robot automation company specialized in AI driven robotization. Its Chief Technology Officer, Max Smith, says a new wave of improvements should be expected for next year.
#         [Position]: Chief Technology Officer
#         ###
#         [Text]: François is a Go developer. He mostly works as a freelancer but is open to any kind of job offering!
#         [Position]: Go developer
#         ###
#         [Text]: Maxime is a data scientist at Auto Dataset, and he's been working there for 1 year.
#         [Position]:"""
# )

# Tokenize prompt, load to GPU with model
input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

# Generate response tokens from GPT-J
gen_tokens = model.generate(
    input_ids,
    do_sample=True,
    num_beams=1,
    temperature=0.1,
    max_new_tokens=128,
    repetition_penalty=1.1,
    top_p=1,
    early_stopping=True
)

# Retrieve generated text
gen_text = tokenizer.batch_decode(gen_tokens)[0]

# Remove prompt from generated text and print
# Split by 'Answer' and take the fourth part
part_after_third_answer = gen_text.split('Answer:')[3]

# Split this part by '###' and take the first part
extracted_string = part_after_third_answer.split('###')[0]

# Remove leading and trailing whitespaces
extracted_string = extracted_string.strip()

print(extracted_string)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# SELECT COUNT(*) FROM Department WHERE age > 56

# %%
#two cells to set up file structure
# Save model output to Drive
model_name = "GPT-J"
technique = "pretrained"
version = 1
# checkpoint = "checkpoint-3504"
inference_model = "GPT-J-standard"

folder_name = f"{model_name}_{technique}_{version}"
# train_path = f"results/{folder_name}"
# model_path = train_path + f'/{folder_name}'
# last_check_point = train_path + f'/checkpoint-2190'
result_path = f'results/{folder_name}/predicted_result_{inference_model}_{version}.txt'


# print("train_path:", train_path)
# print("model_path:", model_path)
print("result_path:", result_path)

# with open(result_path, 'w') as f:
#     for idx, output in enumerate(outputs):
#         db_id = dev_spider.iloc[idx]['db_id']
#         f.write(output + '\t' + db_id + '\n')
# Out:
# result_path: results/GPT-J_pretrained_1/predicted_result_GPT-J-standard_1.txt

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !touch results/GPT-J_pretrained_1/predicted_result_GPT-J-standard_1.txt

# %%
print(prompt)
# Out:
# Context: | ref_document_types : document_type_code , document_type_description | roles : role_code , role_description | addresses : address_id , address_details | ref_document_status : document_status_code , document_status_description | ref_shipping_agents : shipping_agent_code , shipping_agent_name , shipping_agent_description | documents : document_id , document_status_code , document_type_code , shipping_agent_code , receipt_date , receipt_number , other_details | employees : employee_id , role_code , employee_name , other_details | document_drafts : document_id , draft_number , draft_details | draft_copies : document_id , draft_number , copy_number | circulation_history : document_id , draft_number , copy_number , employee_id | documents_mailed : document_id , mailed_to_address_id , mailing_date
#            Question: Which employee has showed up in most circulation history documents. List the employee's name and the number of drafts and copies.
# "
#            Answer: SELECT Employees.employee_name , count(*) FROM Employees JOIN Circulation_History ON Circulation_History.employee_id = Employees.employee_id GROUP BY Circulation_History.document_id , Circulation_History.draft_number , Circulation_History.copy_number ORDER BY count(*) DESC LIMIT 1;
#            ###
#            Context:| member : member_id , card_number , name , hometown , level | branch : branch_id , name , open_year , address_road , city , membership_amount | membership_register_branch : member_id , branch_id , register_year | purchase : member_id , branch_id , year , total_pounds
#            Question: What are names for top three branches with most number of membership?
#            Answer: SELECT name FROM branch ORDER BY membership_amount DESC LIMIT 3
#            ###
#            Context: | department : department_id , name , creation , ranking , budget_in_billions , num_employees | head : head_id , name , born_state , age | management : department_id , head_id , temporary_acting
#            Question: How many heads of the departments are older than 56?
#            Answer:

# %%
print(gen_text)
# Out:
# Context: | ref_document_types : document_type_code, document_type_description | roles : role_code, role_description | addresses : address_id, address_details | ref_document_status : document_status_code, document_status_description | ref_shipping_agents : shipping_agent_code, shipping_agent_name, shipping_agent_description | documents : document_id, document_status_code, document_type_code, shipping_agent_code, receipt_date, receipt_number, other_details | employees : employee_id, role_code, employee_name, other_details | document_drafts : document_id, draft_number, draft_details | draft_copies : document_id, draft_number, copy_number | circulation_history : document_id, draft_number, copy_number, employee_id | documents_mailed : document_id, mailed_to_address_id, mailing_date
#            Question: Which employee has showed up in most circulation history documents. List the employee's name and the number of drafts and copies.
# "
#            Answer: SELECT Employees.employee_name, count(*) FROM Employees JOIN Circulation_History ON Circulation_History.employee_id = Employees.employee_id GROUP BY Circulation_History.document_id, Circulation_History.draft_number, Circulation_History.copy_number ORDER BY count(*) DESC LIMIT 1;
#            ###
#            Context:| member : member_id, card_number, name, hometown, level | branch : branch_id, name, open_year, address_road, city, membership_amount | membership_register_branch : member_id, branch_id, register_year | purchase : member_id, branch_id, year, total_pounds
#            Question: What are names for top three branches with most number of membership?
#            Answer: SELECT name FROM branch ORDER BY membership_amount DESC LIMIT 3
#            ###
#            Context: | department : department_id, name, creation, ranking, budget_in_billions, num_employees | head : head_id, name, born_state, age | management : department_id, head_id, temporary_acting
#            Question: How many heads of the departments are older than 56?
#            Answer:  SELECT COUNT(*) FROM Department WHERE age > 56
#            ###
#            Context: | department : department_id, name, creation, ranking, budget_in_billions, num_employees | head : head_id, name, born_state, age | management : department_id, head_id, temporary_acting
#            Question: How many heads of the departments are younger than 40?
#            Answer:  SELECT C

# %% [markdown]
# # Construct prompts for baseline test

# %% [markdown]
# ## Baseline test of pretrained GPT-J for Spider dataset

# %%
# Instruction style prompt
# prefix = '\n-- Parse the question into SQL based on the given table below.--\n\n'
# infix = '\n Based on this schema, create an ANSI-92 SQL Query to answer the following question:\n'
# postfix = '\n Your response should be in SQL.'


# train_spider['schema'] = train_spider['db_id'].map(schema_dict)
# train_spider['prompt'] = prefix + train_spider['schema'] + infix + train_spider['question'] + postfix

# others_spider['schema'] = others_spider['db_id'].map(schema_dict)
# others_spider['prompt'] = prefix + others_spider['schema'] + infix + others_spider['question']

# dev_spider['schema'] = dev_spider['db_id'].map(schema_dict)
# dev_spider['prompt'] = prefix + dev_spider['schema'] + infix + dev_spider['question'] + postfix

# %%
# Few-shot training style prompt
fixed_few_shot_prefix = """Context: | ref_document_types : document_type_code , document_type_description | roles : role_code , role_description | addresses : address_id , address_details | ref_document_status : document_status_code , document_status_description | ref_shipping_agents : shipping_agent_code , shipping_agent_name , shipping_agent_description | documents : document_id , document_status_code , document_type_code , shipping_agent_code , receipt_date , receipt_number , other_details | employees : employee_id , role_code , employee_name , other_details | document_drafts : document_id , draft_number , draft_details | draft_copies : document_id , draft_number , copy_number | circulation_history : document_id , draft_number , copy_number , employee_id | documents_mailed : document_id , mailed_to_address_id , mailing_date
           Question: Which employee has showed up in most circulation history documents. List the employee's name and the number of drafts and copies.\n"
           Answer: SELECT Employees.employee_name , count(*) FROM Employees JOIN Circulation_History ON Circulation_History.employee_id = Employees.employee_id GROUP BY Circulation_History.document_id , Circulation_History.draft_number , Circulation_History.copy_number ORDER BY count(*) DESC LIMIT 1;
           ###
           Context:| member : member_id , card_number , name , hometown , level | branch : branch_id , name , open_year , address_road , city , membership_amount | membership_register_branch : member_id , branch_id , register_year | purchase : member_id , branch_id , year , total_pounds
           Question: What are names for top three branches with most number of membership?
           Answer: SELECT name FROM branch ORDER BY membership_amount DESC LIMIT 3
           ###
           Context: """

fixed_few_shot_infix = "\n Question: "
fixed_few_shot_postfix = "\n Answer: "

train_spider['schema'] = train_spider['db_id'].map(schema_dict)
train_spider['prompt'] = fixed_few_shot_prefix + train_spider['schema'] + fixed_few_shot_infix + train_spider['question'] + fixed_few_shot_postfix

others_spider['schema'] = others_spider['db_id'].map(schema_dict)
others_spider['prompt'] = fixed_few_shot_prefix + others_spider['schema'] + fixed_few_shot_infix + others_spider['question'] + fixed_few_shot_postfix

dev_spider['schema'] = dev_spider['db_id'].map(schema_dict)
dev_spider['prompt'] = fixed_few_shot_prefix + dev_spider['schema'] + fixed_few_shot_infix + dev_spider['question'] + fixed_few_shot_postfix

# %%
dev_spider['prompt'][0]
# Out:
# 'Context: | ref_document_types : document_type_code , document_type_description | roles : role_code , role_description | addresses : address_id , address_details | ref_document_status : document_status_code , document_status_description | ref_shipping_agents : shipping_agent_code , shipping_agent_name , shipping_agent_description | documents : document_id , document_status_code , document_type_code , shipping_agent_code , receipt_date , receipt_number , other_details | employees : employee_id , role_code , employee_name , other_details | document_drafts : document_id , draft_number , draft_details | draft_copies : document_id , draft_number , copy_number | circulation_history : document_id , draft_number , copy_number , employee_id | documents_mailed : document_id , mailed_to_address_id , mailing_date\n           Question: Which employee has showed up in most circulation history documents. List the employee\'s name and the number of drafts and copies.\n"\n           Answer: SELECT Employees.employee_name , count(*) FROM Employees JOIN Circulation_History ON Circulation_History.employee_id = Employees.employee_id GROUP BY Circulation_History.document_id , Circulation_History.draft_number , Circulation_History.copy_number ORDER BY count(*) DESC LIMIT 1;\n           ###\n           Context:| member : member_id , card_number , name , hometown , level | branch : branch_id , name , open_year , address_road , city , membership_amount | membership_register_branch : member_id , branch_id , register_year | purchase : member_id , branch_id , year , total_pounds\n           Question: What are names for top three branches with most number of membership?\n           Answer: SELECT name FROM branch ORDER BY membership_amount DESC LIMIT 3\n           ###\n           Context:  | stadium : stadium_id , location , name , capacity , highest , lowest , average | singer : singer_id , name , country , song_name , song_release_year , age , is_male | concert : concert_id , concert_name , theme , stadium_id , year | singer_in_concert : concert_id , singer_id\n Question: How many singers do we have?\n Answer: '

# %% [markdown]
# ## Run baseline test prior to fine tuning

# %%
torch.cuda.empty_cache()

# %%
# evaluate
torch.cuda.empty_cache()

max_length = 128

tokenizer.add_special_tokens({'pad_token': tokenizer.eos_token})

# Define a list to store outputs
outputs = []

# Process each prompt individually
for prompt in dev_spider['prompt']:
    #print("Prompt ", i)

    input_ids = tokenizer(
            prompt,
            return_tensors='pt',
            truncation=True,
            padding=True,
        ).input_ids.to(device)

    gen_tokens = model.generate(
                input_ids,
                do_sample=True,
                num_beams=1,
                temperature=0.1,
                max_new_tokens=128,
                repetition_penalty=1.1,
                top_p=1,
                early_stopping=True
        )

    #print("Output: ", tokenizer.decode(gen_tokens[0], skip_special_tokens=True))

    # Retrieve generated text
    gen_text = tokenizer.batch_decode(gen_tokens)[0]

    # Remove prompt from generated text and print
    # Split by 'Answer' and take the fourth part
    part_after_third_answer = gen_text.split('Answer:')[3]

    # Split this part by '###' and take the first part
    extracted_string = part_after_third_answer.split('###')[0]

    # Remove leading and trailing whitespaces
    extracted_string = extracted_string.strip()
    #print(extracted_string)
    outputs.append(extracted_string)

    # Clean GPU cache after each iteration to free up memory
    torch.cuda.empty_cache()



# Retrieve responses
#gen_text = tokenizer.batch_decode(gen_tokens)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
len(outputs)
# Out:
# 1034

# %%
# Save model output to Drive
model_name = "GPT-J"
technique = "pretrained"
version = 1
# checkpoint = "checkpoint-3504"
inference_model = "GPT-J-standard"

folder_name = f"{model_name}_{technique}_{version}"
# train_path = f"results/{folder_name}"
# model_path = train_path + f'/{folder_name}'
# last_check_point = train_path + f'/checkpoint-2190'
result_path = f'results/{folder_name}/predicted_result_{inference_model}_{version}.txt'


# print("train_path:", train_path)
# print("model_path:", model_path)
print("result_path:", result_path)

with open(result_path, 'w', encoding='utf-8') as f:
    for idx, output in enumerate(outputs):
        db_id = dev_spider.iloc[idx]['db_id']
        f.write(output + '\t' + db_id + '\n')
# Out:
# result_path: results/GPT-J_pretrained_1/predicted_result_GPT-J-standard_1.txt

# %%
# evaluate results
eval_path = f"third_party/spider/evaluation.py"
gold = f"third_party/spider/evaluation_examples/gold_example.txt"
pred = f"results/GPT-J_pretrained_1/predicted_result_GPT-J-standard_1_clean.txt"
db_dir = f"spider/database"
table = f"spider/tables.json"
etype = "all"

cmd_str = f"python3 \"{eval_path}\" --gold \"{gold}\" --pred \"{pred}\" --db \"{db_dir}\" --table \"{table}\" --etype {etype} "
result = subprocess.run(cmd_str, shell=True, capture_output=True, text=True)

# %%
# print results
pp = pprint.PrettyPrinter(width=160)
#pp.pprint(result.stdout[-4633:])
pp.pprint(result.stdout)
# Out:
# ('eval_err_num:1\n'
#  'easy pred: SELECT COUNT(*) FROM Singers WHERE singer_id IN (SELECT DISTINCT singer_id FROM Singer_In_Concert)\n'
#  'easy gold: SELECT count(*) FROM singer\n'
#  '\n'
#  'eval_err_num:2\n'
#  'easy pred: SELECT COUNT(*) FROM Singers\n'
#  'easy gold: SELECT count(*) FROM singer\n'
#  '\n'
#  'medium pred: SELECT name, country, age FROM Singer WHERE age > (SELECT MAX(age) FROM Singer) ORDER BY age ASC LIMIT 10\n'
#  'medium gold: SELECT name ,  country ,  age FROM singer ORDER BY age DESC\n'
#  '\n'
#  'eval_err_num:3\n'
#  'medium pred: SELECT name, country, age FROM singers WHERE is_male = 0 ORDER BY age DESC ;\n'
#  'medium gold: SELECT name ,  country ,  age FROM singer ORDER BY age DESC\n'
#  '\n'
#  'eval_err_num:4\n'
#  "medium pred: SELECT AVG(age) AS avg_age, MIN(age) AS min_age, MAX(age) AS max_age FROM singer WHERE country = 'FR' AND is_male = 0 GROUP BY singer_id\n"
#  "medium gold: SELECT avg(age) ,  min(age) ,  max(age) FROM singer WHERE country  =  'France'\n"
#  '\n'
#  'eval_err_num:5\n'
#  "medium pred: SELECT avg(age) AS average, min(age) AS minimum, max(age) AS maximum FROM singer WHERE country = 'France' AND language = 'French' ;\n"
#  "medium gold: SELECT avg(age) ,  min(age) ,  max(age) FROM singer WHERE country  =  'France'\n"
#  '\n'
#  'eval_err_num:6\n'
#  'medium pred: SELECT singers.name, singers.song_release_year FROM singers JOIN Concert ON singers.id = Concert.singer_id WHERE singers.age < (SELECT MIN(age) '
#  'FROM singers);\n'
#  'medium gold: SELECT song_name ,  song_release_year FROM singer ORDER BY age LIMIT 1\n'
#  '\n'
#  'medium pred: SELECT name, song_release_year FROM singer WHERE age < 10 ORDER BY song_release_year ASC\n'
#  'medium gold: SELECT song_name ,  song_release_year FROM singer ORDER BY age LIMIT 1\n'
#  '\n'
#  'easy pred: SELECT country FROM singer WHERE age > 20 AND is_male = 1 ORDER BY name ASC LIMIT 10\n'
#  'easy gold: SELECT DISTINCT country FROM singer WHERE age  >  20\n'
#  '\n'
#  'eval_err_num:7\n'
#  'medium pred: SELECT country, COUNT(*) AS num_singers FROM Singers GROUP BY country ORDER BY num_singers DESC LIMIT 10\n'
#  'medium gold: SELECT country ,  count(*) FROM singer GROUP BY country\n'
#  '\n'
#  'eval_err_num:8\n'
#  "medium pred: SELECT COUNT(*) FROM singers WHERE country = 'USA' OR country = 'UK' OR country = 'FRANCE' OR country = 'GERMANY' OR country = 'ITALY' OR "
#  "country = 'SPAIN' OR country = 'PORTUGAL' OR country = 'AUSTRIA' OR country = 'BELGIUM' OR country = 'DENMARK' OR country = 'FINLAND' OR country = 'GREECE' "
#  "OR country = 'HUNGARY' OR country = 'IRELAND' OR country = 'INDIA' OR country = 'JAPAN\n"
#  'medium gold: SELECT country ,  count(*) FROM singer GROUP BY country\n'
#  '\n'
#  'hard pred: SELECT name FROM singer WHERE age > (SELECT AVG(age) FROM singer);\n'
#  'hard gold: SELECT song_name FROM singer WHERE age  >  (SELECT avg(age) FROM singer)\n'
#  '\n'
#  'medium pred: SELECT Stadium.location, Stadium.name FROM Stadium WHERE Stadium.capacity BETWEEN 5000 AND 10000 ORDER BY Stadium.capacity DESC LIMIT 10\n'
#  'medium gold: SELECT LOCATION ,  name FROM stadium WHERE capacity BETWEEN 5000 AND 10000\n'
#  '\n'
#  'eval_err_num:9\n'
#  'medium pred: SELECT station_location, name FROM station WHERE capacity BETWEEN 5000 AND 10000 ORDER BY name ASC\n'
#  'medium gold: SELECT LOCATION ,  name FROM stadium WHERE capacity BETWEEN 5000 AND 10000\n'
#  '\n'
#  'eval_err_num:10\n'
#  'medium pred: SELECT MAX(capacity) AS max_capacity, AVG(capacity) AS avg_capacity FROM Stadium WHERE stadium_id IN (SELECT stadium_id FROM Stadium_Concert '
#  "WHERE stadium_id = '1')\n"
#  'medium gold: SELECT avg(capacity) ,  max(capacity) FROM stadium\n'
#  '\n'
#  'eval_err_num:11\n'
#  'medium pred: SELECT AVG(capacity) AS avg_capacity, MAX(capacity) AS max_capacity FROM Stadium WHERE stadium_id IN (SELECT stadium_id FROM Stadium_Concert '
#  "WHERE singer_id = '1' AND concert_id = '2')\n"
#  'medium gold: SELECT avg(capacity) ,  max(capacity) FROM stadium\n'
#  '\n'
#  'medium pred: SELECT name, capacity FROM stadium WHERE highest > (SELECT AVG(highest) FROM stadium);\n'
#  'medium gold: SELECT name ,  capacity FROM stadium ORDER BY average DESC LIMIT 1\n'
#  '\n'
#  'medium pred: SELECT name, capacity FROM stadium WHERE highest > (SELECT AVG(highest) FROM stadium);\n'
#  'medium gold: SELECT name ,  capacity FROM stadium ORDER BY average DESC LIMIT 1\n'
#  '\n'
#  'eval_err_num:12\n'
#  'medium pred: SELECT COUNT(*) FROM Concert WHERE year IN (2014,2015)\n'
#  'medium gold: SELECT count(*) FROM concert WHERE YEAR  =  2014 OR YEAR  =  2015\n'
#  '\n'
#  'eval_err_num:13\n'
#  'medium pred: SELECT COUNT(*) FROM Concert WHERE year IN (2014,2015)\n'
#  'medium gold: SELECT count(*) FROM concert WHERE YEAR  =  2014 OR YEAR  =  2015\n'
#  '\n'
#  'eval_err_num:14\n'
#  'medium pred: SELECT stadiums.stadium_name, count(*) FROM Stadiums JOIN Concerts ON Concerts.stadium_id = Stadiums.stadium_id GROUP BY Stadiums.stadium_id '
#  'ORDER BY count(*) DESC LIMIT 10;\n'
#  'medium gold: SELECT T2.name ,  count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id GROUP BY T1.stadium_id\n'
#  '\n'
#  'medium pred: SELECT COUNT(*) FROM Stadium WHERE stadium_id IN (SELECT stadium_id FROM Concert)\n'
#  'medium gold: SELECT T2.name ,  count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id GROUP BY T1.stadium_id\n'
#  '\n'
#  'eval_err_num:15\n'
#  "extra pred: SELECT Stadium.name, Stadium.capacity FROM Stadium JOIN Concert ON Stadium.stadium_id = Concert.stadium_id WHERE (Concert.year >= '2014') AND "
#  "(Concert.year <= '2015');\n"
#  'extra gold: SELECT T2.name ,  T2.capacity FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  >=  2014 GROUP BY '
#  'T2.stadium_id ORDER BY count(*) DESC LIMIT 1\n'
#  '\n'
#  'eval_err_num:16\n'
#  "extra pred: SELECT name, capacity FROM stadium WHERE year >= '2013' AND year <= '2014' ORDER BY capacity DESC LIMIT 1\n"
#  'extra gold: SELECT T2.name ,  T2.capacity FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  >=  2014 GROUP BY '
#  'T2.stadium_id ORDER BY count(*) DESC LIMIT 1\n'
#  '\n'
#  'eval_err_num:17\n'
#  'hard pred: SELECT CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( '
#  'CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( '
#  'CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONC\n'
#  'hard gold: SELECT YEAR FROM concert GROUP BY YEAR ORDER BY count(*) DESC LIMIT 1\n'
#  '\n'
#  'eval_err_num:18\n'
#  'hard pred: SELECT CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( '
#  'CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( '
#  'CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONC\n'
#  'hard gold: SELECT YEAR FROM concert GROUP BY YEAR ORDER BY count(*) DESC LIMIT 1\n'
#  '\n'
#  'eval_err_num:19\n'
#  'hard pred: SELECT Stadium.stadium_name FROM Stadium LEFT OUTER JOIN Concert ON Stadium.stadium_id = Concert.stadium_id WHERE Concert.concert_id IS NULL\n'
#  'hard gold: SELECT name FROM stadium WHERE stadium_id NOT IN (SELECT stadium_id FROM concert)\n'
#  '\n'
#  'eval_err_num:20\n'
#  'hard pred: SELECT Stadium.name FROM Stadium WHERE Stadium.concert_id IS NULL\n'
#  'hard gold: SELECT name FROM stadium WHERE stadium_id NOT IN (SELECT stadium_id FROM concert)\n'
#  '\n'
#  'eval_err_num:21\n'
#  'hard pred: SELECT DISTINCT country FROM singers WHERE (age BETWEEN 40 AND 50) OR (age < 30);\n'
#  'hard gold: SELECT country FROM singer WHERE age  >  40 INTERSECT SELECT country FROM singer WHERE age  <  30\n'
#  '\n'
#  'eval_err_num:22\n'
#  'hard pred: SELECT Stadium.stadium_name, Concert.concert_name FROM Stadium LEFT OUTER JOIN Concert ON Stadium.stadium_id = Concert.stadium_id WHERE '
#  "Concert.concert_year!= '2014' ORDER BY Stadium.stadium_name ASC\n"
#  'hard gold: SELECT name FROM stadium EXCEPT SELECT T2.name FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  =  2014\n'
#  '\n'
#  'eval_err_num:23\n'
#  "hard pred: SELECT Stadium.stadium_name FROM Stadium LEFT OUTER JOIN Concert ON Stadium.stadium_id = Concert.stadium_id WHERE Concert.year = '2014' AND "
#  'Concert.is_male = 0\n'
#  'hard gold: SELECT name FROM stadium EXCEPT SELECT T2.name FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  =  2014\n'
#  '\n'
#  'eval_err_num:24\n'
#  'medium pred: SELECT CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( '
#  'CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( '
#  'CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONCAT ( CONC\n'
#  'medium gold: SELECT T2.concert_name ,  T2.theme ,  count(*) FROM singer_in_concert AS T1 JOIN concert AS T2 ON T1.concert_id  =  T2.concert_id GROUP BY '
#  'T2.concert_id\n'
#  '\n'
#  'eval_err_num:25\n'
#  "medium pred: SELECT CONCAT (Singer.name,'', Singer.country) AS name, CONCAT (Theme.theme,'', Theme.song_name) AS theme, COUNT(*) AS num_singers FROM "
#  'Concerts JOIN Singers ON Singers.concert_id = Concerts.concert_id JOIN Themes ON Themes.concert_id = Concerts.concert_id JOIN Songs ON Songs.concert_id = '
#  'Concerts.concert_id WHERE Stadium.stadium_id = Concerts.stadium_id AND Theme.theme = Songs.theme GROUP BY Concerts.\n'
#  'medium gold: SELECT T2.concert_name ,  T2.theme ,  count(*) FROM singer_in_concert AS T1 JOIN concert AS T2 ON T1.concert_id  =  T2.concert_id GROUP BY '
#  'T2.concert_id\n'
#  '\n'
#  'eval_err_num:26\n'
#  'medium pred: SELECT singers.name, COUNT(*) AS num_of_concerts FROM Singers JOIN Concerts ON Concerts.singers_id = Singers.singers_id GROUP BY singers.name '
#  'ORDER BY num_of_concerts DESC LIMIT 10\n'
#  'medium gold: SELECT T2.name ,  count(*) FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id GROUP BY T2.singer_id\n'
#  '\n'
#  'eval_err_num:27\n'
#  'medium pred: SELECT name, COUNT(*) AS num_concerts FROM Singers JOIN Concerts ON Singers.singer_id = Concerts.singer_id GROUP BY name ORDER BY num_concerts '
#  'DESC LIMIT 10\n'
#  'medium gold: SELECT T2.name ,  count(*) FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id GROUP BY T2.singer_id\n'
#  '\n'
#  'eval_err_num:28\n'
#  "hard pred: SELECT DISTINCT singers.name FROM singers INNER JOIN Concerts ON (Concerts.singer_id = singers.id) WHERE (Concerts.year = '2014') AND "
#  "(Concerts.stadium_id = '1')\n"
#  'hard gold: SELECT T2.name FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id JOIN concert AS T3 ON T1.concert_id  =  '
#  'T3.concert_id WHERE T3.year  =  2014\n'
#  '\n'
#  "hard pred: SELECT name FROM singer WHERE song_release_year = '2014' AND is_male = 0\n"
#  'hard gold: SELECT T2.name FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id JOIN concert AS T3 ON T1.concert_id  =  '
#  'T3.concert_id WHERE T3.year  =  2014\n'
#  '\n'
#  'eval_err_num:29\n'
#  "extra pred: SELECT Stadium.location, Stadium.name FROM Stadium JOIN Concert ON Concert.stadium_id = Stadium.stadium_id WHERE (Concert.year IN ('2014', "
#  "'2015')) AND (Concert.year = '2015') OR (Concert.year = '2014');\n"
#  'extra gold: SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2014 INTERSECT SELECT '
#  'T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2015\n'
#  '\n'
#  'eval_err_num:30\n'
#  'extra pred: SELECT Stadium.stadium_name, Location.location_name FROM Stadium JOIN Concert ON Concert.stadium_id = Stadium.stadium_id WHERE '
#  "(Concert.concert_year IN ('2014', '2015')) AND (Concert.concert_theme = 'Rock')\n"
#  'extra gold: SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2014 INTERSECT SELECT '
#  'T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2015\n'
#  '\n'
#  'eval_err_num:31\n'
#  'hard pred: SELECT COUNT(*) FROM Stadium WHERE stadium_id IN (SELECT stadium_id FROM Concert WHERE stadium_id=?)\n'
#  'hard gold: SELECT count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id ORDER BY T2.Capacity DESC LIMIT 1\n'
#  '\n'
#  'eval_err_num:32\n'
#  'hard pred: SELECT COUNT(*) FROM Concerts WHERE Stadium_ID = (SELECT MAX(Stadium_ID) FROM Stadium);\n'
#  'hard gold: SELECT count(*) FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id ORDER BY T2.Capacity DESC LIMIT 1\n'
#  '\n'
#  'medium pred: SELECT weight FROM pets WHERE pet_age = (SELECT MIN(pet_age) FROM pets);\n'
#  'medium gold: SELECT weight FROM pets ORDER BY pet_age LIMIT 1\n'
#  '\n'
#  'medium pred: SELECT weight FROM pets WHERE pet_age = (SELECT MIN(pet_age) FROM pets);\n'
#  'medium gold: SELECT weight FROM pets ORDER BY pet_age LIMIT 1\n'
#  '\n'
#  'eval_err_num:33\n'
#  "medium pred: SELECT MAX(weight) AS max_weight, pettype FROM Pets WHERE pettype IN ('cat', 'dog') GROUP BY pettype\n"
#  'medium gold: SELECT max(weight) ,  petType FROM pets GROUP BY petType\n'
#  '\n'
#  'eval_err_num:34\n'
#  "medium pred: SELECT MAX(weight) AS max_weight, pettype FROM Pets WHERE pettype IN ('dog', 'cat') GROUP BY pettype\n"
#  'medium gold: SELECT max(weight) ,  petType FROM pets GROUP BY petType\n'
#  '\n'
#  'eval_err_num:35\n'
#  'medium pred: SELECT COUNT(*) FROM Pets WHERE (student.stuid > 20) AND (Pets.pet_age >= 20);\n'
#  'medium gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20\n'
#  '\n'
#  'eval_err_num:36\n'
#  'medium pred: SELECT COUNT(*) FROM Students JOIN Pets ON Students.stuid = Pets.stuid WHERE Pets.age > 20 ;\n'
#  'medium gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20\n'
#  '\n'
#  'eval_err_num:37\n'
#  "hard pred: SELECT COUNT(DISTINCT CASE WHEN sex = 'F' THEN petid END) FROM Pets WHERE student =? AND sex = 'F'\n"
#  "hard gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND "
#  "T3.pettype  =  'dog'\n"
#  '\n'
#  'eval_err_num:38\n'
#  'hard pred: SELECT COUNT(*) FROM Student_Pets WHERE student_id =? AND sex =?\n'
#  "hard gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND "
#  "T3.pettype  =  'dog'\n"
#  '\n'
#  'eval_err_num:39\n'
#  'extra pred: SELECT Students.fname, Students.lname, Students.sex, Students.age, Students.major, Students.advisor, Students.city_code, Pets.pet_type, '
#  'Pets.weight, Pets.pet_age, Pets.pet_id, Pets.pet_name, Pets.owner_stuid, Pets.owner_lname, Pets.owner_fname, Pets.owner_age, Pets.owner_sex, '
#  'Pets.owner_major, Pets.owner_advisor, Pets.owner_city_code, Pets.owner_city_name, Pets.owner_\n'
#  'extra gold: SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE '
#  "T3.pettype  =  'cat' OR T3.pettype  =  'dog'\n"
#  '\n'
#  'eval_err_num:40\n'
#  'extra pred: SELECT Students.fname, Students.lname, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code, Pets.pet_type, '
#  "Pets.weight, Pets.pet_age, Pets.petid, Pets.pettype FROM Students LEFT OUTER JOIN Pets ON Pets.stuid = Students.stuid AND Pets.pet_type IN ('cat', 'dog') "
#  'WHERE Students.has_pet = 1 ORDER BY Students.stuid ASC, Students.fname ASC, Students.lname ASC, Students.age ASC, Students.sex ASC\n'
#  'extra gold: SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE '
#  "T3.pettype  =  'cat' OR T3.pettype  =  'dog'\n"
#  '\n'
#  'eval_err_num:41\n'
#  "extra pred: SELECT Students.fname FROM Students WHERE (Students.has_pet = '1' AND Students.petid IN ('2', '3'));\n"
#  'extra gold: SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  '
#  "'cat' INTERSECT SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  "
#  "'dog'\n"
#  '\n'
#  'eval_err_num:42\n'
#  'extra pred: SELECT Students.fname, Students.lname, Students.sex, Students.age, Students.major, Students.advisor, Students.city_code, Pets.pet_type, '
#  'Pets.weight, Pets.pet_age, Pets.petid, Pets.pettype, Pets.pet_age, Pets.petid, Pets.pettype, Pets.pet_age, Pets.petid, Pets.pettype, Pets.pet_age, '
#  'Pets.petid, Pets.pettype, Pets.pet_age, Pets.petid, Pets.pettype, Pets.pet_\n'
#  'extra gold: SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  '
#  "'cat' INTERSECT SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  "
#  "'dog'\n"
#  '\n'
#  'eval_err_num:43\n'
#  'extra pred: SELECT Students.stuid, Students.lname, Students.fname, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code, '
#  'Students.has_pet, Pets.petid, Pets.pettype, Pets.pet_age, Pets.weight FROM Students LEFT OUTER JOIN Pets ON (Pets.stuid = Students.stuid) WHERE '
#  'Students.has_pet IS NULL AND Pets.petid IS NULL\n'
#  'extra gold: SELECT major ,  age FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS '
#  "T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')\n"
#  '\n'
#  'eval_err_num:44\n'
#  'extra pred: SELECT Students.stuid, Students.lname, Students.fname, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code, '
#  'COUNT(Students.has_pet) AS no_of_cats, AVG(Students.weight) AS avg_weight FROM Students LEFT OUTER JOIN Pets ON (Pets.student_id = Students.stuid ) WHERE '
#  "Students.has_pet IS NULL AND Students.city_code IN ('US') AND Students.age > 18 GROUP BY Students.stuid, Students.lname, Students.fname\n"
#  'extra gold: SELECT major ,  age FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS '
#  "T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')\n"
#  '\n'
#  'eval_err_num:45\n'
#  'hard pred: SELECT Students.stuid, Students.lname, Students.fname, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code FROM '
#  'Students LEFT OUTER JOIN Pets ON Pets.student_id = Students.stuid WHERE Pets.petid IS NULL ;\n'
#  'hard gold: SELECT stuid FROM student EXCEPT SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  '
#  "T2.petid WHERE T3.pettype  =  'cat'\n"
#  '\n'
#  'eval_err_num:46\n'
#  'hard pred: SELECT Students.stuid, Students.lname, Students.fname, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code, '
#  'Students.has_pet, Students.petid, Students.pettype, Students.pet_age, Students.weight FROM Students WHERE NOT EXISTS (SELECT * FROM Pets WHERE Pets.stuid = '
#  'Students.stuid AND Pets.petid = Students.petid)\n'
#  'hard gold: SELECT stuid FROM student EXCEPT SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  '
#  "T2.petid WHERE T3.pettype  =  'cat'\n"
#  '\n'
#  'eval_err_num:47\n'
#  'extra pred: SELECT Students.fname, Students.lname, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code, Students.has_pet, '
#  'Students.petid, Students.pettype, Students.pet_age, Students.weight FROM Students WHERE Students.has_pet = 0 AND Students.petid IS NOT NULL ORDER BY '
#  'Students.age ASC LIMIT 10\n'
#  'extra gold: SELECT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE '
#  "T3.pettype  =  'dog' AND T1.stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  "
#  "T2.petid WHERE T3.pettype  =  'cat')\n"
#  '\n'
#  'eval_err_num:48\n'
#  'extra pred: SELECT Students.fname, Students.lname, Students.sex, Students.age, Students.major, Students.advisor, Students.city_code, Students.has_pet, '
#  'Pets.pet_id, Pets.pettype, Pets.pet_age, Pets.weight FROM Students LEFT OUTER JOIN Pets ON (Pets.stuid = Students.stuid) WHERE Students.has_pet = 0 AND '
#  'Pets.pet_id IS NOT NULL\n'
#  'extra gold: SELECT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE '
#  "T3.pettype  =  'dog' AND T1.stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  "
#  "T2.petid WHERE T3.pettype  =  'cat')\n"
#  '\n'
#  'eval_err_num:49\n'
#  'medium pred: SELECT pet_type, weight FROM Pets WHERE pet_age = (SELECT MIN(pet_age) FROM Pets);\n'
#  'medium gold: SELECT pettype ,  weight FROM pets ORDER BY pet_age LIMIT 1\n'
#  '\n'
#  'eval_err_num:50\n'
#  "medium pred: SELECT pet_type, pet_age, weight FROM Pets WHERE pet_type = 'dog' AND pet_age = (SELECT MIN(pet_age) FROM Pets);\n"
#  'medium gold: SELECT pettype ,  weight FROM pets ORDER BY pet_age LIMIT 1\n'
#  '\n'
#  'eval_err_num:51\n'
#  'medium pred: SELECT * FROM Pets WHERE age > 1 AND pet_age > 0\n'
#  'medium gold: SELECT petid ,  weight FROM pets WHERE pet_age  >  1\n'
#  '\n'
#  'eval_err_num:52\n'
#  'medium pred: SELECT pet_id, weight FROM Pets WHERE age > 1 ORDER BY weight DESC LIMIT 10\n'
#  'medium gold: SELECT petid ,  weight FROM pets WHERE pet_age  >  1\n'
#  '\n'
#  'eval_err_num:53\n'
#  "medium pred: SELECT AVG(age) AS avg_age, MAX(age) AS max_age FROM pets WHERE pettype IN ('cat', 'dog') GROUP BY pettype\n"
#  'medium gold: SELECT avg(pet_age) ,  max(pet_age) ,  pettype FROM pets GROUP BY pettype\n'
#  '\n'
#  'eval_err_num:54\n'
#  "medium pred: SELECT AVG(pet_age) AS avg_age, MAX(pet_age) AS max_age FROM pets WHERE pettype IN ('dog', 'cat') GROUP BY pettype\n"
#  'medium gold: SELECT avg(pet_age) ,  max(pet_age) ,  pettype FROM pets GROUP BY pettype\n'
#  '\n'
#  'eval_err_num:55\n'
#  "medium pred: SELECT AVG(weight) FROM Pets WHERE PetType IN ('dog', 'cat')\n"
#  'medium gold: SELECT avg(weight) ,  pettype FROM pets GROUP BY pettype\n'
#  '\n'
#  'eval_err_num:56\n'
#  "medium pred: SELECT AVG(weight) FROM Pets WHERE PetType IN ('Cat', 'Dog') AND PetAge > 0 GROUP BY PetType\n"
#  'medium gold: SELECT avg(weight) ,  pettype FROM pets GROUP BY pettype\n'
#  '\n'
#  'eval_err_num:57\n'
#  'medium pred: SELECT Students.fname, Students.lname, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code, Pets.weight, '
#  'Pets.pet_age, Pets.pettype, Pets.petid, Pets.pet_name, Pets.owner_stuid, Pets.owner_lname, Pets.owner_fname, Pets.owner_age, Pets.owner_sex, '
#  'Pets.owner_major, Pets.owner_advisor, Pets.owner_city_code, Pets.owner_city_name, Pets.owner_state_\n'
#  'medium gold: SELECT DISTINCT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid\n'
#  '\n'
#  'eval_err_num:58\n'
#  'medium pred: SELECT Students.fname, Students.lname, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code, Pets.weight, '
#  'Pets.pet_age, Pets.pettype, Pets.petid, Pets.pet_name, Pets.pet_owner, Pets.pet_birthday, Pets.pet_breed, Pets.pet_color, Pets.pet_size, Pets.pet_gender, '
#  'Pets.pet_dob, Pets.pet_type, Pets.pet_owner_id, Pets.pet_birthday, Pets.\n'
#  'medium gold: SELECT DISTINCT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid\n'
#  '\n'
#  'eval_err_num:59\n'
#  "medium pred: SELECT Pets.pet_id FROM Pets WHERE Pets.student_id = '$stuid' AND Pets.lname = '$lname' AND Pets.fname = '$fname' AND Pets.age = '$age' AND "
#  "Pets.sex = '$sex' AND Pets.major = '$major' AND Pets.advisor = '$advisor' AND Pets.city_code = '$city_code'\n"
#  "medium gold: SELECT T2.petid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.Lname  =  'Smith'\n"
#  '\n'
#  'eval_err_num:60\n'
#  "medium pred: SELECT Pets.pet_id FROM Students JOIN Pets ON Students.stuid = Pets.stuid WHERE LOWER(LNAME) ='smith' ;\n"
#  "medium gold: SELECT T2.petid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.Lname  =  'Smith'\n"
#  '\n'
#  'eval_err_num:61\n'
#  'medium pred: SELECT COUNT(*) FROM Pets WHERE student_id IN (SELECT stuid FROM Students) AND pet_id IN (SELECT petid FROM Pets);\n'
#  'medium gold: SELECT count(*) ,  T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid\n'
#  '\n'
#  'eval_err_num:62\n'
#  'medium pred: SELECT Students.stuid, count(Students.stuid) FROM Students LEFT OUTER JOIN Pets ON Students.stuid = Pets.stuid GROUP BY Students.stuid ORDER BY '
#  'count(Students.stuid) DESC LIMIT 10\n'
#  'medium gold: SELECT count(*) ,  T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid\n'
#  '\n'
#  'eval_err_num:63\n'
#  'medium pred: SELECT Students.fname, Students.lname, Students.gender, Students.age, Students.sex, Students.major, Students.advisor, Students.city_code, '
#  'Students.has_pet, Pets.petid, Pets.pettype, Pets.pet_age, Pets.weight FROM Students LEFT OUTER JOIN Pets ON (Pets.stuid = Students.stuid) WHERE '
#  'Students.has_pet > 0 AND Students.has_pet < 2 ORDER BY Students.has_pet DESC LIMIT 1;\n'
#  'medium gold: SELECT T1.fname ,  T1.sex FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid HAVING count(*)  >  1\n'
#  '\n'
#  'eval_err_num:64\n'
#  'medium pred: SELECT Students.fname, Students.lname, Students.sex, Students.age, Students.major, Students.advisor, Students.city_code, Students.has_pet, '
#  "Students.petid, Students.pettype, Students.pet_age, Students.weight FROM Students WHERE (Students.has_pet = '1' AND Students.petid IN (SELECT DISTINCT "
#  "Pet.petid FROM Pets AS Pet)) OR (Students.has_pet = '0' AND Students.petid NOT IN (SELECT DISTINCT Pet.petid FROM Pets AS Pet));\n"
#  'medium gold: SELECT T1.fname ,  T1.sex FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid GROUP BY T1.stuid HAVING count(*)  >  1\n'
#  '\n'
#  'eval_err_num:65\n'
#  "hard pred: SELECT Students.lname FROM Students JOIN Pets ON Pets.student_id = Students.stuid WHERE Pets.pet_age = 3 AND Pets.pettype = 'cat' ORDER BY "
#  'Students.fname ASC LIMIT 1\n'
#  'hard gold: SELECT T1.lname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pet_age  =  3 '
#  "AND T3.pettype  =  'cat'\n"
#  '\n'
#  'eval_err_num:66\n'
#  'hard pred: SELECT lname FROM students WHERE (SELECT COUNT(*) FROM pets WHERE students.stuid = pets.stuid AND pets.pet_age = 3) > 0\n'
#  'hard gold: SELECT T1.lname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pet_age  =  3 '
#  "AND T3.pettype  =  'cat'\n"
#  '\n'
#  'eval_err_num:67\n'
#  'extra pred: SELECT AVG(age) FROM Students WHERE has_pet = 0 ;\n'
#  'extra gold: SELECT avg(age) FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid)\n'
#  '\n'
#  'eval_err_num:68\n'
#  'extra pred: SELECT AVG(age) FROM Students WHERE has_pet = 0\n'
#  'extra gold: SELECT avg(age) FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid)\n'
#  '\n'
#  'easy pred: SELECT COUNT(continent) FROM continents\n'
#  'easy gold: SELECT count(*) FROM CONTINENTS;\n'
#  '\n'
#  'medium pred: SELECT continent, count(*) FROM countries GROUP BY continent ORDER BY count(*) DESC LIMIT 3\n'
#  'medium gold: SELECT T1.ContId ,  T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.Continent GROUP BY T1.ContId;\n'
#  '\n'
#  'eval_err_num:69\n'
#  'medium pred: SELECT continent, count(country) FROM countries GROUP BY continent ORDER BY count(country) DESC LIMIT 10\n'
#  'medium gold: SELECT T1.ContId ,  T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.Continent GROUP BY T1.ContId;\n'
#  '\n'
#  "easy pred: SELECT COUNT(*) FROM countries WHERE continent = 'Europe'\n"
#  'easy gold: SELECT count(*) FROM COUNTRIES;\n'
#  '\n'
#  'eval_err_num:70\n'
#  'medium pred: SELECT maker, fullname, count(*) FROM cars_data GROUP BY maker ;\n'
#  'medium gold: SELECT T1.FullName ,  T1.Id ,  count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id;\n'
#  '\n'
#  'eval_err_num:71\n'
#  'medium pred: SELECT maker, fullname, COUNT(*) AS num FROM cars_data WHERE makeid IN (SELECT id FROM car_makers) GROUP BY maker ORDER BY num DESC LIMIT 10\n'
#  'medium gold: SELECT T1.FullName ,  T1.Id ,  count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id;\n'
#  '\n'
#  'eval_err_num:72\n'
#  'hard pred: SELECT model, MIN(horsepower) FROM cars_data WHERE makeid=1 AND modelid=2 GROUP BY model\n'
#  'hard gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.horsepower ASC LIMIT 1;\n'
#  '\n'
#  'eval_err_num:73\n'
#  'hard pred: SELECT model FROM cars_data WHERE horsepower < (SELECT MIN(horsepower) FROM cars_data);\n'
#  'hard gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.horsepower ASC LIMIT 1;\n'
#  '\n'
#  'extra pred: SELECT * FROM cars_data WHERE weight < (SELECT AVG(weight) FROM cars_data);\n'
#  'extra gold: SELECT T1.model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Weight  <  (SELECT avg(Weight) FROM CARS_DATA)\n'
#  '\n'
#  'eval_err_num:74\n'
#  'extra pred: SELECT model FROM cars_data WHERE weight < (SELECT AVG(weight) FROM cars_data);\n'
#  'extra gold: SELECT T1.model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Weight  <  (SELECT avg(Weight) FROM CARS_DATA)\n'
#  '\n'
#  'eval_err_num:75\n'
#  "extra pred: SELECT maker, fullname FROM cars_data WHERE year = '1970' AND mpg > 0 ORDER BY mpg DESC LIMIT 10\n"
#  'extra gold: SELECT DISTINCT T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker JOIN CAR_NAMES AS T3 ON T2.model  =  T3.model JOIN '
#  "CARS_DATA AS T4 ON T3.MakeId  =  T4.id WHERE T4.year  =  '1970';\n"
#  '\n'
#  'eval_err_num:76\n'
#  "extra pred: SELECT DISTINCT maker FROM cars_data WHERE YEAR = '1970' AND mpg > 0 ORDER BY mpg DESC LIMIT 10\n"
#  'extra gold: SELECT DISTINCT T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker JOIN CAR_NAMES AS T3 ON T2.model  =  T3.model JOIN '
#  "CARS_DATA AS T4 ON T3.MakeId  =  T4.id WHERE T4.year  =  '1970';\n"
#  '\n'
#  'eval_err_num:77\n'
#  'extra pred: SELECT Cars.makeid, Cars.model, Cars.mpg, Cars.cylinders, Cars.edispl, Cars.horsepower, Cars.weight, Cars.accelerate, Cars.year FROM Cars WHERE '
#  'Cars.year = (SELECT MIN(cars_data.year) FROM Cars AS cars_data WHERE cars_data.maker = Cars.maker AND cars_data.model = Cars.model);\n'
#  'extra gold: SELECT T2.Make ,  T1.Year FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T1.Year  =  (SELECT min(YEAR) FROM CARS_DATA);\n'
#  '\n'
#  'eval_err_num:78\n'
#  'extra pred: SELECT maker, year FROM cars_data WHERE mpg > 0 AND cylinders > 4 AND edispl > 2 AND accelerate > 0 AND year < 2000 ORDER BY year ASC LIMIT 1;\n'
#  'extra gold: SELECT T2.Make ,  T1.Year FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T1.Year  =  (SELECT min(YEAR) FROM CARS_DATA);\n'
#  '\n'
#  'eval_err_num:79\n'
#  'hard pred: SELECT DISTINCT model FROM cars_data WHERE YEAR >= 1980 ORDER BY YEAR DESC LIMIT 10\n'
#  'hard gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.model  =  T2.model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.id WHERE '
#  'T3.year  >  1980;\n'
#  '\n'
#  'eval_err_num:80\n'
#  'hard pred: SELECT * FROM cars_data WHERE year >= 1980 AND year <= 1990 ORDER BY model ASC\n'
#  'hard gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.model  =  T2.model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.id WHERE '
#  'T3.year  >  1980;\n'
#  '\n'
#  'hard pred: SELECT continent, count(*) FROM countries GROUP BY continent ORDER BY count(*) DESC LIMIT 10\n'
#  'hard gold: SELECT T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.continent JOIN car_makers AS T3 ON T2.CountryId  '
#  '=  T3.Country GROUP BY T1.Continent;\n'
#  '\n'
#  'eval_err_num:81\n'
#  'hard pred: SELECT continent, COUNT(*) AS num_car_maker FROM car_makers GROUP BY continent ;\n'
#  'hard gold: SELECT T1.Continent ,  count(*) FROM CONTINENTS AS T1 JOIN COUNTRIES AS T2 ON T1.ContId  =  T2.continent JOIN car_makers AS T3 ON T2.CountryId  '
#  '=  T3.Country GROUP BY T1.Continent;\n'
#  '\n'
#  'eval_err_num:82\n'
#  'extra pred: SELECT country FROM countries WHERE country IN (SELECT DISTINCT country FROM car_makers) ORDER BY COUNT(DISTINCT country) DESC LIMIT 5\n'
#  'extra gold: SELECT T2.CountryName FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId GROUP BY T1.Country ORDER BY Count(*) DESC LIMIT '
#  '1;\n'
#  '\n'
#  'eval_err_num:83\n'
#  'extra pred: SELECT countryname FROM countries WHERE countryid IN (SELECT countryid FROM car_makers) ORDER BY COUNT(car_makers.countryid) DESC LIMIT 1\n'
#  'extra gold: SELECT T2.CountryName FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId GROUP BY T1.Country ORDER BY Count(*) DESC LIMIT '
#  '1;\n'
#  '\n'
#  'eval_err_num:84\n'
#  'medium pred: SELECT COUNT(*), maker FROM cars_data WHERE makeid IN (SELECT maker FROM car_makers) GROUP BY maker ORDER BY COUNT(*) DESC, maker\n'
#  'medium gold: SELECT Count(*) ,  T2.FullName ,  T2.id FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id GROUP BY T2.id;\n'
#  '\n'
#  'eval_err_num:85\n'
#  'medium pred: SELECT maker, model, make, fullname FROM car_names WHERE makeid IN (SELECT id FROM car_makers) AND modelid IN (SELECT id FROM model_list);\n'
#  'medium gold: SELECT Count(*) ,  T2.FullName ,  T2.id FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id GROUP BY T2.id;\n'
#  '\n'
#  'medium pred: SELECT * FROM cars_data WHERE mpg > 50 AND cylinders > 4 AND accelerate > 2 ORDER BY accelerate DESC LIMIT 1\n'
#  "medium gold: SELECT T1.Accelerate FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Make  =  'amc hornet sportabout (sw)';\n"
#  '\n'
#  'eval_err_num:86\n'
#  "medium pred: SELECT COUNT(*) FROM car_makers WHERE country = 'FR' AND continent = 'EU'\n"
#  "medium gold: SELECT T1.Accelerate FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Make  =  'amc hornet sportabout (sw)';\n"
#  '\n'
#  'eval_err_num:87\n'
#  "medium pred: SELECT COUNT(*) FROM cars_data WHERE country = 'France' AND maker = 'Ford'\n"
#  "medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId WHERE T2.CountryName  =  'france';\n"
#  '\n'
#  'eval_err_num:88\n'
#  "medium pred: SELECT COUNT(*) FROM cars_data WHERE country = 'USA' AND model LIKE '%car%'\n"
#  "medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId WHERE T2.CountryName  =  'france';\n"
#  '\n'
#  'eval_err_num:89\n'
#  "hard pred: SELECT COUNT(*) FROM cars_data WHERE country = 'United States' AND maker = 'Ford'\n"
#  'hard gold: SELECT count(*) FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id JOIN COUNTRIES AS T3 ON T2.Country  =  T3.CountryId WHERE '
#  "T3.CountryName  =  'usa';\n"
#  '\n'
#  'hard pred: SELECT AVG (cars_data.mpg ) FROM cars_data WHERE cars_data.cylinders = 4 ;\n'
#  'hard gold: SELECT count(*) FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id JOIN COUNTRIES AS T3 ON T2.Country  =  T3.CountryId WHERE '
#  "T3.CountryName  =  'usa';\n"
#  '\n'
#  "easy pred: SELECT MIN (weight) FROM cars_data WHERE cylinders = 8 AND year = '1974'\n"
#  'easy gold: SELECT avg(mpg) FROM CARS_DATA WHERE Cylinders  =  4;\n'
#  '\n'
#  "hard pred: SELECT MIN (weight) FROM cars_data WHERE cylinders = 8 AND YEAR = '1974'\n"
#  'hard gold: SELECT Weight FROM CARS_DATA WHERE Cylinders  =  4 AND YEAR  =  1974 ORDER BY Weight ASC LIMIT 1;\n'
#  '\n'
#  'eval_err_num:90\n'
#  'hard pred: SELECT * FROM car_names WHERE makeid IN (SELECT id FROM car_makers) AND modelid IN (SELECT id FROM model_list);\n'
#  'hard gold: SELECT Weight FROM CARS_DATA WHERE Cylinders  =  4 AND YEAR  =  1974 ORDER BY Weight ASC LIMIT 1;\n'
#  '\n'
#  'eval_err_num:91\n'
#  'medium pred: SELECT DISTINCT maker, model FROM cars_data WHERE id IN (SELECT id FROM model_list) AND id IN (SELECT id FROM car_names);\n'
#  'medium gold: SELECT Maker ,  Model FROM MODEL_LIST;\n'
#  '\n'
#  'eval_err_num:92\n'
#  'medium pred: SELECT countryname, countryid FROM countries WHERE EXISTS (SELECT * FROM car_makers WHERE countryid = countries.countryid)\n'
#  'medium gold: SELECT Maker ,  Model FROM MODEL_LIST;\n'
#  '\n'
#  'eval_err_num:93\n'
#  'medium pred: SELECT * FROM countries WHERE EXISTS (SELECT * FROM car_makers WHERE countries.countryid = car_makers.countryid)\n'
#  'medium gold: SELECT T1.CountryName ,  T1.CountryId FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.CountryId HAVING '
#  'count(*)  >=  1;\n'
#  '\n'
#  'medium pred: SELECT COUNT(*) FROM cars_data WHERE horsepower > 150\n'
#  'medium gold: SELECT T1.CountryName ,  T1.CountryId FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.CountryId HAVING '
#  'count(*)  >=  1;\n'
#  '\n'
#  'eval_err_num:94\n'
#  'easy pred: SELECT AVG(weight) FROM cars_data WHERE YEAR(curdate()) = YEAR(now()) AND MONTH(curdate()) = MONTH(now()) AND DAYOFMONTH(curdate()) = '
#  'DAYOFMONTH(now());\n'
#  'easy gold: SELECT count(*) FROM CARS_DATA WHERE horsepower  >  150;\n'
#  '\n'
#  'eval_err_num:95\n'
#  'medium pred: SELECT AVG(weight) AS avg_weight, YEAR(receipt_date) AS year FROM cars_data WHERE YEAR(receipt_date) BETWEEN 2000 AND 2010 GROUP BY '
#  'YEAR(receipt_date)\n'
#  'medium gold: SELECT avg(Weight) ,  YEAR FROM CARS_DATA GROUP BY YEAR;\n'
#  '\n'
#  'eval_err_num:96\n'
#  'medium pred: SELECT * FROM countries WHERE (SELECT COUNT(*) FROM car_makers WHERE countryid=c.countryid)>3\n'
#  'medium gold: SELECT avg(Weight) ,  YEAR FROM CARS_DATA GROUP BY YEAR;\n'
#  '\n'
#  'eval_err_num:97\n'
#  'extra pred: SELECT DISTINCT countryname FROM countries WHERE COUNT(DISTINCT manufacturer) >= 3\n'
#  'extra gold: SELECT T1.CountryName FROM COUNTRIES AS T1 JOIN CONTINENTS AS T2 ON T1.Continent  =  T2.ContId JOIN CAR_MAKERS AS T3 ON T1.CountryId  =  '
#  "T3.Country WHERE T2.Continent  =  'europe' GROUP BY T1.CountryName HAVING count(*)  >=  3;\n"
#  '\n'
#  'eval_err_num:98\n'
#  "extra pred: SELECT max(horsepower) as hp, make from cars_data WHERE cylinders=3 AND model='Fiat'\n"
#  'extra gold: SELECT T1.CountryName FROM COUNTRIES AS T1 JOIN CONTINENTS AS T2 ON T1.Continent  =  T2.ContId JOIN CAR_MAKERS AS T3 ON T1.CountryId  =  '
#  "T3.Country WHERE T2.Continent  =  'europe' GROUP BY T1.CountryName HAVING count(*)  >=  3;\n"
#  '\n'
#  'eval_err_num:99\n'
#  "extra pred: SELECT * FROM cars_data WHERE cylinders = 3 AND model = 'Volkswagen' ORDER BY horsepower DESC LIMIT 1\n"
#  'extra gold: SELECT T2.horsepower ,  T1.Make FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.cylinders  =  3 ORDER BY T2.horsepower '
#  'DESC LIMIT 1;\n'
#  '\n'
#  'eval_err_num:100\n'
#  'extra pred: SELECT model, mpg FROM cars_data WHERE mpg > (SELECT AVG(mpg) FROM cars_data);\n'
#  'extra gold: SELECT T2.horsepower ,  T1.Make FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.cylinders  =  3 ORDER BY T2.horsepower '
#  'DESC LIMIT 1;\n'
#  '\n'
#  'hard pred: SELECT * FROM cars_data WHERE mpg > (SELECT max(mpg) FROM cars_data);\n'
#  'hard gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.mpg DESC LIMIT 1;\n'
#  '\n'
#  'hard pred: SELECT AVG (horsepower) FROM cars_data WHERE YEAR < 1980\n'
#  'hard gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.mpg DESC LIMIT 1;\n'
#  '\n'
#  'eval_err_num:101\n'
#  "easy pred: SELECT AVG (edispl) FROM cars_data WHERE model = 'volvo'\n"
#  'easy gold: SELECT avg(horsepower) FROM CARS_DATA WHERE YEAR  <  1980;\n'
#  '\n'
#  'eval_err_num:102\n'
#  "medium pred: SELECT AVG ( edispl ) FROM cars_data WHERE makeid = 'volvo' ;\n"
#  "medium gold: SELECT avg(T2.edispl) FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T1.Model  =  'volvo';\n"
#  '\n'
#  'medium pred: SELECT max(accelerate) FROM cars_data WHERE cylinders > 4 AND cylinders < 8\n'
#  "medium gold: SELECT avg(T2.edispl) FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T1.Model  =  'volvo';\n"
#  '\n'
#  'medium pred: SELECT max(accelerate) FROM cars_data WHERE cylinders = 4\n'
#  'medium gold: SELECT max(Accelerate) ,  Cylinders FROM CARS_DATA GROUP BY Cylinders;\n'
#  '\n'
#  'eval_err_num:103\n'
#  'medium pred: SELECT model, COUNT(*) AS num FROM cars_data WHERE makeid IN (SELECT DISTINCT makeid FROM car_names) AND modelid IN (SELECT DISTINCT modelid '
#  'FROM car_names) GROUP BY model ORDER BY num DESC LIMIT 10\n'
#  'medium gold: SELECT max(Accelerate) ,  Cylinders FROM CARS_DATA GROUP BY Cylinders;\n'
#  '\n'
#  'eval_err_num:104\n'
#  'hard pred: SELECT model, COUNT(DISTINCT version) AS num_versions FROM cars_data WHERE model NOT IN (SELECT DISTINCT model FROM cars_data) GROUP BY model '
#  'ORDER BY num_versions DESC LIMIT 5\n'
#  'hard gold: SELECT Model FROM CAR_NAMES GROUP BY Model ORDER BY count(*) DESC LIMIT 1;\n'
#  '\n'
#  'hard pred: SELECT COUNT(*) FROM cars_data WHERE cylinders > 4\n'
#  'hard gold: SELECT Model FROM CAR_NAMES GROUP BY Model ORDER BY count(*) DESC LIMIT 1;\n'
#  '\n'
#  'eval_err_num:105\n'
#  'easy pred: SELECT COUNT(*) FROM cars_data WHERE year=1980\n'
#  'easy gold: SELECT count(*) FROM CARS_DATA WHERE Cylinders  >  4;\n'
#  '\n'
#  'eval_err_num:106\n'
#  "easy pred: SELECT * FROM (SELECT COUNT(*) AS `count` FROM `cars_data` WHERE `year`='1980') AS `subquery`\n"
#  'easy gold: SELECT count(*) FROM CARS_DATA WHERE YEAR  =  1980;\n'
#  '\n'
#  'eval_err_num:107\n'
#  "medium pred: SELECT COUNT(*) FROM cars_data WHERE maker = 'American Motor Company' AND model LIKE '%Company%'\n"
#  "medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker WHERE T1.FullName  =  'American Motor Company';\n"
#  '\n'
#  'eval_err_num:108\n'
#  "medium pred: SELECT COUNT(*) FROM cars_data WHERE maker = 'American Motors'\n"
#  "medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker WHERE T1.FullName  =  'American Motor Company';\n"
#  '\n'
#  'eval_err_num:109\n'
#  'medium pred: SELECT maker, fullname FROM car_names WHERE maker IN (SELECT maker FROM car_makers WHERE id IN (SELECT id FROM model_list WHERE modelid IN '
#  '(SELECT id FROM cars_data WHERE mpg > 4 AND cylinders > 2 AND edispl > 0 AND horsepower > 200)))\n'
#  'medium gold: SELECT T1.FullName ,  T1.Id FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id HAVING count(*)  >  3;\n'
#  '\n'
#  'eval_err_num:110\n'
#  'medium pred: SELECT maker, model, make, COUNT(*) AS num FROM cars_data WHERE COUNT(*) > 3 GROUP BY maker, model, make\n'
#  'medium gold: SELECT T1.FullName ,  T1.Id FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id HAVING count(*)  >  3;\n'
#  '\n'
#  'eval_err_num:111\n'
#  "extra pred: SELECT distinct(model) FROM cars_data WHERE maker = 'General Motors' AND weight > 3500\n"
#  'extra gold: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model  =  T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker  =  T3.Id JOIN '
#  "CARS_DATA AS T4 ON T1.MakeId  =  T4.Id WHERE T3.FullName  =  'General Motors' OR T4.weight  >  3500;\n"
#  '\n'
#  'eval_err_num:112\n'
#  'extra pred: SELECT * FROM cars_data WHERE (mpg > 35 AND cylinders > 4) OR (weight > 3500 AND horsepower > 300)\n'
#  'extra gold: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model  =  T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker  =  T3.Id JOIN '
#  "CARS_DATA AS T4 ON T1.MakeId  =  T4.Id WHERE T3.FullName  =  'General Motors' OR T4.weight  >  3500;\n"
#  '\n'
#  'eval_err_num:113\n'
#  'medium pred: SELECT YEAR(cars_data.year) AS year, SUM(cars_data.weight) AS weight, COUNT(cars_data.mpg) AS mpg, COUNT(cars_data.cylinders) AS cylinders, '
#  'COUNT(cars_data.edispl) AS edispl, COUNT(cars_data.horsepower) AS horsepower, COUNT(cars_data.accelerate) AS accelerate FROM cars_data WHERE '
#  '(cars_data.weight >= 3000 AND cars_data.weight <= 4000) AND (cars_data.mpg > 0 AND cars_data\n'
#  'medium gold: SELECT DISTINCT T1.Year FROM CARS_DATA AS T1 WHERE T1.Weight  >  3000 AND T1.weight  <  4000;\n'
#  '\n'
#  'eval_err_num:114\n'
#  'medium pred: SELECT YEAR(cars_data.year) AS year, COUNT(cars_data.mpg) AS mpg, COUNT(cars_data.cylinders) AS cylinders, COUNT(cars_data.edispl) AS edispl, '
#  'COUNT(cars_data.horsepower) AS horsepower, COUNT(cars_data.weight) AS weight, COUNT(cars_data.accelerate) AS accelerate, COUNT(cars_data.year) AS year FROM '
#  'cars_data WHERE (cars_data.weight < 4000 OR cars_data.weight > 3000) AND\n'
#  'medium gold: SELECT DISTINCT T1.Year FROM CARS_DATA AS T1 WHERE T1.Weight  >  3000 AND T1.weight  <  4000;\n'
#  '\n'
#  "medium pred: SELECT horsepower FROM cars_data WHERE accelerate > 0 AND YEAR = '2017' AND MPG > 0 ORDER BY accelerate DESC LIMIT 1\n"
#  'medium gold: SELECT T1.horsepower FROM CARS_DATA AS T1 ORDER BY T1.accelerate DESC LIMIT 1;\n'
#  '\n'
#  'medium pred: SELECT horsepower FROM cars_data WHERE accelerate > (SELECT MAX(accelerate) FROM cars_data);\n'
#  'medium gold: SELECT T1.horsepower FROM CARS_DATA AS T1 ORDER BY T1.accelerate DESC LIMIT 1;\n'
#  '\n'
#  "extra pred: SELECT COUNT(*) FROM cars_data WHERE mpg < '3' AND cylinders > '4'\n"
#  "extra gold: SELECT T1.cylinders FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Model  =  'volvo' ORDER BY T1.accelerate ASC LIMIT "
#  '1;\n'
#  '\n'
#  'eval_err_num:115\n'
#  "extra pred: SELECT COUNT(*) FROM cars_data WHERE modelid = '1' AND maker = 'Volvo' AND model = 'S40' AND accelerate < '2' ;\n"
#  "extra gold: SELECT T1.cylinders FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Model  =  'volvo' ORDER BY T1.accelerate ASC LIMIT "
#  '1;\n'
#  '\n'
#  'hard pred: SELECT COUNT(*) FROM cars_data WHERE accelerate > (SELECT MAX(accelerate) FROM cars_data);\n'
#  'hard gold: SELECT COUNT(*) FROM CARS_DATA WHERE Accelerate  >  ( SELECT Accelerate FROM CARS_DATA ORDER BY Horsepower DESC LIMIT 1 );\n'
#  '\n'
#  'hard pred: SELECT COUNT(*) FROM cars_data WHERE accelerate > (SELECT MAX(accelerate) FROM cars_data);\n'
#  'hard gold: SELECT COUNT(*) FROM CARS_DATA WHERE Accelerate  >  ( SELECT Accelerate FROM CARS_DATA ORDER BY Horsepower DESC LIMIT 1 );\n'
#  '\n'
#  'eval_err_num:116\n'
#  'easy pred: SELECT COUNT(*) FROM countries WHERE countryid IN (SELECT DISTINCT countryid FROM car_makers) AND COUNT(*) > 2\n'
#  'easy gold: SELECT COUNT(*) FROM ( SELECT T1.CountryId ,  COUNT(*) FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY '
#  'T1.CountryId HAVING count(*)  >  2 );\n'
#  '\n'
#  'eval_err_num:117\n'
#  'easy pred: SELECT COUNT(*) FROM Countries WHERE countryid IN (SELECT DISTINCT countryid FROM Car_Makers) AND COUNT(*) > 2\n'
#  'easy gold: SELECT COUNT(*) FROM ( SELECT T1.CountryId ,  COUNT(*) FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY '
#  'T1.CountryId HAVING count(*)  >  2 );\n'
#  '\n'
#  'eval_err_num:118\n'
#  "extra pred: SELECT model, max(horsepower) FROM cars_data WHERE cylinders=4 AND model!='Volkswagen' GROUP BY model\n"
#  'extra gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Cylinders  =  4 ORDER BY T2.horsepower DESC LIMIT 1;\n'
#  '\n'
#  'eval_err_num:119\n'
# ...
#  "'2019-01-01' AND Course_Arrange.grade = 'A'\n"
#  'hard gold: SELECT T3.Name ,  T2.Course FROM course_arrange AS T1 JOIN course AS T2 ON T1.Course_ID  =  T2.Course_ID JOIN teacher AS T3 ON T1.Teacher_ID  =  '
#  'T3.Teacher_ID ORDER BY T3.Name\n'
#  '\n'
#  'eval_err_num:283\n'
#  'hard pred: SELECT Teacher.teacher_name, Teacher.age, Teacher.hometown FROM Teacher JOIN Course ON Teacher.teacher_id = Course.teacher_id WHERE '
#  "Course.course_id IN (SELECT Course.course_id FROM Course JOIN Course_Arrange ON Course_Arrange.course_id = Course.course_id WHERE Course_Arrange.grade = 'A' "
#  "AND Course_Arrange.staring_date < '2018-01-01') ORDER BY Teacher.age ASC, Teacher.hometown ASC\n"
#  'hard gold: SELECT T3.Name FROM course_arrange AS T1 JOIN course AS T2 ON T1.Course_ID  =  T2.Course_ID JOIN teacher AS T3 ON T1.Teacher_ID  =  T3.Teacher_ID '
#  'WHERE T2.Course  =  "Math"\n'
#  '\n'
#  'eval_err_num:284\n'
#  'hard pred: SELECT Teachers.teacher_name, COUNT(*) AS `courses` FROM Teachers JOIN Course_Arrange ON Course_Arrange.teacher_id = Teachers.teacher_id GROUP BY '
#  'Course_Arrange.course_id ORDER BY `courses` DESC LIMIT 10\n'
#  'hard gold: SELECT T3.Name FROM course_arrange AS T1 JOIN course AS T2 ON T1.Course_ID  =  T2.Course_ID JOIN teacher AS T3 ON T1.Teacher_ID  =  T3.Teacher_ID '
#  'WHERE T2.Course  =  "Math"\n'
#  '\n'
#  'eval_err_num:285\n'
#  'medium pred: SELECT Teacher.teacher_name, COUNT(course) FROM Course JOIN Teacher ON Teacher.teacher_id = Course.teacher_id GROUP BY Teacher.teacher_name '
#  'ORDER BY COUNT(course) DESC LIMIT 10\n'
#  'medium gold: SELECT T2.Name ,  COUNT(*) FROM course_arrange AS T1 JOIN teacher AS T2 ON T1.Teacher_ID  =  T2.Teacher_ID GROUP BY T2.Name\n'
#  '\n'
#  'eval_err_num:286\n'
#  'medium pred: SELECT Teachers.teacher_name, COUNT(DISTINCT Courses.course_id) AS CourseCount FROM Teachers JOIN Courses ON Courses.teacher_id = '
#  'Teachers.teacher_id WHERE (Teachers.age > 18 AND Teachers.age < 30) GROUP BY Teachers.teacher_name HAVING CourseCount >= 2\n'
#  'medium gold: SELECT T2.Name ,  COUNT(*) FROM course_arrange AS T1 JOIN teacher AS T2 ON T1.Teacher_ID  =  T2.Teacher_ID GROUP BY T2.Name\n'
#  '\n'
#  'eval_err_num:287\n'
#  'medium pred: SELECT Teacher.teacher_name FROM Course JOIN Course_Arrange ON Course_Arrange.course_id = Course.course_id WHERE Course_Arrange.grade >= 2 AND '
#  'Course_Arrange.teacher_id IN (SELECT Teacher.teacher_id FROM Teacher)\n'
#  'medium gold: SELECT T2.Name FROM course_arrange AS T1 JOIN teacher AS T2 ON T1.Teacher_ID  =  T2.Teacher_ID GROUP BY T2.Name HAVING COUNT(*)  >=  2\n'
#  '\n'
#  'eval_err_num:288\n'
#  'medium pred: SELECT Teachers.teacher_name FROM Course_Arrange LEFT JOIN Teachers ON Course_Arrange.teacher_id = Teachers.teacher_id WHERE '
#  'Course_Arrange.course_id IS NULL\n'
#  'medium gold: SELECT T2.Name FROM course_arrange AS T1 JOIN teacher AS T2 ON T1.Teacher_ID  =  T2.Teacher_ID GROUP BY T2.Name HAVING COUNT(*)  >=  2\n'
#  '\n'
#  'eval_err_num:289\n'
#  'hard pred: SELECT Teacher.teacher_name FROM Course_Arrange LEFT JOIN Teacher ON Course_Arrange.teacher_id = Teacher.teacher_id WHERE '
#  'Course_Arrange.course_id NOT IN (SELECT Course_Arrange2.course_id FROM Course_Arrange2) AND Course_Arrange.staring_date IS NULL\n'
#  'hard gold: SELECT Name FROM teacher WHERE Teacher_id NOT IN (SELECT Teacher_id FROM course_arrange)\n'
#  '\n'
#  'eval_err_num:290\n'
#  'hard pred: SELECT COUNT(*) FROM Visitors WHERE age < 30\n'
#  'hard gold: SELECT Name FROM teacher WHERE Teacher_id NOT IN (SELECT Teacher_id FROM course_arrange)\n'
#  '\n'
#  'eval_err_num:291\n'
#  'easy pred: SELECT Visitors.name, Visitors.level_of_membership FROM Visitors WHERE Visitors.level_of_membership > 4 ORDER BY Visitors.level_of_membership ASC '
#  'LIMIT 10\n'
#  'easy gold: SELECT count(*) FROM visitor WHERE age  <  30\n'
#  '\n'
#  'medium pred: SELECT AVG(age) FROM visitor WHERE level_of_membership < 4\n'
#  'medium gold: SELECT name FROM visitor WHERE Level_of_membership  >  4 ORDER BY Level_of_membership DESC\n'
#  '\n'
#  'eval_err_num:292\n'
#  'easy pred: SELECT Visitors.name, Visitors.level_of_membership FROM Visitors WHERE Visitors.level_of_membership > 4 ORDER BY Visitors.age ASC\n'
#  'easy gold: SELECT avg(age) FROM visitor WHERE Level_of_membership  <=  4\n'
#  '\n'
#  'eval_err_num:293\n'
#  'medium pred: SELECT Museum.museum_id, Museum.name FROM Museum LEFT JOIN Staff ON Museum.museum_id = Staff.museum_id WHERE (Staff.num_of_staff) > (SELECT '
#  'max(num_of_staff) FROM Staff);\n'
#  'medium gold: SELECT name ,  Level_of_membership FROM visitor WHERE Level_of_membership  >  4 ORDER BY age DESC\n'
#  '\n'
#  'medium pred: SELECT AVG(num_of_staff) FROM museum WHERE open_year < 2009\n'
#  'medium gold: SELECT museum_id ,  name FROM museum ORDER BY num_of_staff DESC LIMIT 1\n'
#  '\n'
#  "easy pred: SELECT name, open_year, num_of_staff FROM museum WHERE name = 'Plaza Museum'\n"
#  'easy gold: SELECT avg(num_of_staff) FROM museum WHERE open_year  <  2009\n'
#  '\n'
#  'medium pred: SELECT name FROM museum WHERE num_of_staff > (SELECT MIN(num_of_staff) FROM museum);\n'
#  "medium gold: SELECT Num_of_Staff ,  Open_Year FROM museum WHERE name  =  'Plaza Museum'\n"
#  '\n'
#  'eval_err_num:294\n'
#  'hard pred: SELECT Visitors.visitor_id, Visitors.name, Visitors.age FROM Visitors JOIN Visit ON Visit.visitor_id = Visitors.visitor_id WHERE '
#  'Visit.num_of_ticket > 1\n'
#  'hard gold: SELECT name FROM museum WHERE num_of_staff  >  (SELECT min(num_of_staff) FROM museum WHERE open_year  >  2010)\n'
#  '\n'
#  'eval_err_num:295\n'
#  'medium pred: SELECT visitor_id, name, level_of_membership, age, max(total_spent) AS total_spent FROM visitor WHERE (visitor_id IN (SELECT museum_id FROM '
#  "visit)) AND (level_of_membership IN ('Gold', 'Silver')) GROUP BY visitor_id\n"
#  'medium gold: SELECT t1.id ,  t1.name ,  t1.age FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id GROUP BY t1.id HAVING count(*)  >  1\n'
#  '\n'
#  'eval_err_num:296\n'
#  'extra pred: SELECT Visitors.visitor_id, Visitors.name, COUNT(Visitors.visitor_id) AS visits FROM Visitors GROUP BY Visitors.visitor_id ORDER BY visits DESC '
#  'LIMIT 10\n'
#  'extra gold: SELECT t2.visitor_id ,  t1.name ,  t1.Level_of_membership FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id GROUP BY t2.visitor_id '
#  'ORDER BY sum(t2.Total_spent) DESC LIMIT 1\n'
#  '\n'
#  'extra pred: SELECT name FROM museum WHERE num_of_staff = 0 ;\n'
#  'extra gold: SELECT t2.Museum_ID ,  t1.name FROM museum AS t1 JOIN visit AS t2 ON t1.Museum_ID  =  t2.Museum_ID GROUP BY t2.Museum_ID ORDER BY count(*) DESC '
#  'LIMIT 1\n'
#  '\n'
#  'eval_err_num:297\n'
#  "hard pred: SELECT Visitors.name, Visitors.age FROM Visitors JOIN Visit ON Visit.visitor_id = Visitors.id WHERE Visitors.level_of_membership = '1' AND "
#  'Visitors.num_of_ticket > (SELECT MAX(Visitors.num_of_ticket) FROM Visitors);\n'
#  'hard gold: SELECT name FROM museum WHERE Museum_ID NOT IN (SELECT museum_id FROM visit)\n'
#  '\n'
#  'eval_err_num:298\n'
#  'hard pred: SELECT AVG(num_of_ticket) AS avg_num_of_ticket, MAX(num_of_ticket) AS max_num_of_ticket FROM visit WHERE museum_id =? ;\n'
#  'hard gold: SELECT t1.name ,  t1.age FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id ORDER BY t2.num_of_ticket DESC LIMIT 1\n'
#  '\n'
#  'eval_err_num:299\n'
#  "medium pred: SELECT SUM(total_spent) FROM visit WHERE level_of_membership = '1' AND visitor_id IN (SELECT visitor_id FROM visit WHERE level_of_membership = "
#  "'1')\n"
#  'medium gold: SELECT avg(num_of_ticket) ,  max(num_of_ticket) FROM visit\n'
#  '\n'
#  'eval_err_num:300\n'
#  'medium pred: SELECT name FROM visitor WHERE (visitor_id IN (SELECT visitor_id FROM visit WHERE museum_id=1) AND (visit.museum_id<>1)) OR (visitor_id IN '
#  '(SELECT visitor_id FROM visit WHERE museum_id=2) AND (visit.museum_id<>2))\n'
#  'medium gold: SELECT sum(t2.Total_spent) FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id WHERE t1.Level_of_membership  =  1\n'
#  '\n'
#  'eval_err_num:301\n'
#  "extra pred: SELECT COUNT(visitor_id) FROM visit WHERE museum_id NOT IN (SELECT museum_id FROM museum WHERE open_year < '2010') AND visitor_id IS NOT NULL\n"
#  'extra gold: SELECT t1.name FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id JOIN museum AS t3 ON t3.Museum_ID  =  t2.Museum_ID WHERE '
#  't3.open_year  <  2009 INTERSECT SELECT t1.name FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id JOIN museum AS t3 ON t3.Museum_ID  =  '
#  't2.Museum_ID WHERE t3.open_year  >  2011\n'
#  '\n'
#  "extra pred: SELECT COUNT(*) FROM Museum WHERE open_year >= '2013' AND open_year <= '2008';\n"
#  'extra gold: SELECT count(*) FROM visitor WHERE id NOT IN (SELECT t2.visitor_id FROM museum AS t1 JOIN visit AS t2 ON t1.Museum_ID  =  t2.Museum_ID WHERE '
#  't1.open_year  >  2010)\n'
#  '\n'
#  'eval_err_num:302\n'
#  'medium pred: SELECT COUNT(*) FROM Players\n'
#  'medium gold: SELECT count(*) FROM museum WHERE open_year  >  2013 OR open_year  <  2008\n'
#  '\n'
#  'easy pred: SELECT COUNT(*) FROM Matches\n'
#  'easy gold: SELECT count(*) FROM players\n'
#  '\n'
#  "easy pred: SELECT COUNT(matches.match_num) FROM matches WHERE matches.tourney_id = '$tourneys' AND matches.winner_id = '$winners' AND matches.loser_id = "
#  "'$losers' AND matches.round = '$rounds' AND matches.score > 0\n"
#  'easy gold: SELECT count(*) FROM matches\n'
#  '\n'
#  "easy pred: SELECT first_name, birth_date FROM Players WHERE country_code = 'US'\n"
#  'easy gold: SELECT count(*) FROM matches\n'
#  '\n'
#  "medium pred: SELECT first_name, birth_date FROM Players WHERE country_code = 'US' AND birth_date > '1940-01-01' ORDER BY birth_date ASC LIMIT 10\n"
#  "medium gold: SELECT first_name ,  birth_date FROM players WHERE country_code  =  'USA'\n"
#  '\n'
#  'eval_err_num:303\n'
#  'medium pred: SELECT AVG(loser_age) AS avg_age, AVG(winner_age) AS avg_age FROM (SELECT loser_age, winner_age FROM matches WHERE tournament_id = '
#  "'$tourney_id' AND winner_id!= '$player_id') AS t1 GROUP BY player_id\n"
#  "medium gold: SELECT first_name ,  birth_date FROM players WHERE country_code  =  'USA'\n"
#  '\n'
#  'eval_err_num:304\n'
#  'medium pred: SELECT avg(loser_age) AS age, avg(winner_age) AS age2 FROM (SELECT loser_age, winner_age, COUNT(*) AS cnt FROM matches WHERE loser_age > 0 AND '
#  'winner_age > 0 GROUP BY loser_age, winner_age ) t1\n'
#  'medium gold: SELECT avg(loser_age) ,  avg(winner_age) FROM matches\n'
#  '\n'
#  'eval_err_num:305\n'
#  "medium pred: SELECT avg(ranking) FROM rankings WHERE player_id IN (SELECT player_id FROM matches) AND ranking_date BETWEEN '2015-01-01' AND '2016-12-31'\n"
#  'medium gold: SELECT avg(loser_age) ,  avg(winner_age) FROM matches\n'
#  '\n'
#  'eval_err_num:306\n'
#  "easy pred: SELECT avg(ranking) FROM (SELECT ranking, player_id FROM rankings WHERE ranking_date BETWEEN '2015-01-01' AND '2016-12-31') AS t1 GROUP BY "
#  'player_id\n'
#  'easy gold: SELECT avg(winner_rank) FROM matches\n'
#  '\n'
#  'eval_err_num:307\n'
#  "easy pred: SELECT * FROM (SELECT * FROM matches WHERE player_id IN (SELECT player_id FROM players WHERE first_name LIKE '%' ||? || '%' OR last_name LIKE '%' "
#  "||? || '%') AND loser_id NOT IN (SELECT winner_id FROM players WHERE first_name LIKE '%' ||? || '%' OR last_name LIKE '%' ||? || '%')) AS t1 ORDER BY "
#  'ranking_points DESC LIMIT 1\n'
#  'easy gold: SELECT avg(winner_rank) FROM matches\n'
#  '\n'
#  'eval_err_num:308\n'
#  'easy pred: SELECT * FROM (SELECT *, ROW_NUMBER() OVER (PARTITION BY player_id ORDER BY loser_rank) AS rn FROM (SELECT *, RANK() OVER (ORDER BY loser_rank) '
#  'AS loser_rank FROM (SELECT *, ROW_NUMBER() OVER (PARTITION BY player_id ORDER BY loser_rank) AS rn FROM (SELECT *, ROW_NUMBER() OVER (ORDER BY loser_rank) '
#  'AS loser_rank FROM (SELECT *, ROW_NUMBER() OVER (ORDER BY loser_rank) AS loser_rank FROM\n'
#  'easy gold: SELECT min(loser_rank) FROM matches\n'
#  '\n'
#  'easy pred: SELECT COUNT(DISTINCT country_code) FROM Players\n'
#  'easy gold: SELECT min(loser_rank) FROM matches\n'
#  '\n'
#  'eval_err_num:309\n'
#  'easy pred: SELECT COUNT(DISTINCT loser_name) FROM matches WHERE loser_name IS NOT NULL\n'
#  'easy gold: SELECT count(DISTINCT country_code) FROM players\n'
#  '\n'
#  'eval_err_num:310\n'
#  'easy pred: SELECT COUNT(DISTINCT loser_name) FROM losers\n'
#  'easy gold: SELECT count(DISTINCT loser_name) FROM matches\n'
#  '\n'
#  'eval_err_num:311\n'
#  'easy pred: SELECT tourney_name FROM tournaments WHERE COUNT(*) > 10\n'
#  'easy gold: SELECT count(DISTINCT loser_name) FROM matches\n'
#  '\n'
#  'eval_err_num:312\n'
#  'easy pred: SELECT tournament_name FROM tournaments WHERE COUNT(tournaments.match_num) > 10\n'
#  'easy gold: SELECT tourney_name FROM matches GROUP BY tourney_name HAVING count(*)  >  10\n'
#  '\n'
#  'eval_err_num:313\n'
#  'easy pred: SELECT winner_name, winner_age, winner_entry, winner_hand, winner_ht, winner_id, winner_ioc, winner_name, winner_rank, winner_rank_points, '
#  "winner_seed, year FROM Rankings WHERE year IN ( '2013', '2016' ) AND ranking IN ( '1', '2' )\n"
#  'easy gold: SELECT tourney_name FROM matches GROUP BY tourney_name HAVING count(*)  >  10\n'
#  '\n'
#  'eval_err_num:314\n'
#  "hard pred: SELECT * FROM players WHERE (tourney_date BETWEEN '2013-01-01' AND '2016-12-31') AND (winner_name LIKE '%2013%' OR winner_name LIKE '%2016%')\n"
#  'hard gold: SELECT winner_name FROM matches WHERE YEAR  =  2013 INTERSECT SELECT winner_name FROM matches WHERE YEAR  =  2016\n'
#  '\n'
#  'eval_err_num:315\n'
#  'hard pred: SELECT COUNT(*) FROM Matches WHERE YEAR(match_date) IN (2013,2016);\n'
#  'hard gold: SELECT winner_name FROM matches WHERE YEAR  =  2013 INTERSECT SELECT winner_name FROM matches WHERE YEAR  =  2016\n'
#  '\n'
#  'eval_err_num:316\n'
#  "medium pred: SELECT COUNT(*) FROM Matches WHERE YEAR(match_date) = '2013' OR YEAR(match_date) = '2016';\n"
#  'medium gold: SELECT count(*) FROM matches WHERE YEAR  =  2013 OR YEAR  =  2016\n'
#  '\n'
#  'eval_err_num:317\n'
#  "medium pred: SELECT country_code, first_name FROM players WHERE (tourney_name = 'WTA' AND tourney_id = '1') OR (tourney_name = 'Australian Open' AND "
#  "tourney_id = '2');\n"
#  'medium gold: SELECT count(*) FROM matches WHERE YEAR  =  2013 OR YEAR  =  2016\n'
#  '\n'
#  'eval_err_num:318\n'
#  'extra pred: SELECT first_name, country_code FROM players WHERE ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( '
#  '( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( ( (\n'
#  "extra gold: SELECT T1.country_code ,  T1.first_name FROM players AS T1 JOIN matches AS T2 ON T1.player_id  =  T2.winner_id WHERE T2.tourney_name  =  'WTA "
#  "Championships' INTERSECT SELECT T1.country_code ,  T1.first_name FROM players AS T1 JOIN matches AS T2 ON T1.player_id  =  T2.winner_id WHERE "
#  "T2.tourney_name  =  'Australian Open'\n"
#  '\n'
#  'extra pred: SELECT Players.first_name, Players.country_code FROM Players WHERE Players.birth_date = (SELECT max(Players.birth_date) FROM Players);\n'
#  "extra gold: SELECT T1.country_code ,  T1.first_name FROM players AS T1 JOIN matches AS T2 ON T1.player_id  =  T2.winner_id WHERE T2.tourney_name  =  'WTA "
#  "Championships' INTERSECT SELECT T1.country_code ,  T1.first_name FROM players AS T1 JOIN matches AS T2 ON T1.player_id  =  T2.winner_id WHERE "
#  "T2.tourney_name  =  'Australian Open'\n"
#  '\n'
#  'medium pred: SELECT Players.first_name, Players.country_code FROM Players WHERE Players.birth_date = (SELECT max(Players.birth_date) FROM Players);\n'
#  'medium gold: SELECT first_name ,  country_code FROM players ORDER BY birth_date LIMIT 1\n'
#  '\n'
#  'medium pred: SELECT Players.first_name, Players.last_name FROM Players ORDER BY Players.birth_date ASC LIMIT 10\n'
#  'medium gold: SELECT first_name ,  country_code FROM players ORDER BY birth_date LIMIT 1\n'
#  '\n'
#  'eval_err_num:319\n'
#  "medium pred: SELECT CONCAT (first_name,'', last_name) AS full_name, birth_date FROM Players ORDER BY birth_date ASC\n"
#  'medium gold: SELECT first_name ,  last_name FROM players ORDER BY birth_date\n'
#  '\n')

# %%
pprint.pprint(result.stderr)
# Out:
# ('Traceback (most recent call last):\n'
#  '  File '
#  '"/content/drive/MyDrive/Github/w266_project/third_party/spider/evaluation.py", '
#  'line 868, in <module>\n'
#  '    evaluate(gold, pred, db_dir, etype, kmaps)\n'
#  '  File '
#  '"/content/drive/MyDrive/Github/w266_project/third_party/spider/evaluation.py", '
#  'line 547, in evaluate\n'
#  '    exec_score = eval_exec_match(db, p_str, g_str, p_sql, g_sql)\n'
#  '  File '
#  '"/content/drive/MyDrive/Github/w266_project/third_party/spider/evaluation.py", '
#  'line 628, in eval_exec_match\n'
#  '    q_res = cursor.fetchall()\n'
#  "sqlite3.OperationalError: Could not decode to UTF-8 column 'last_name' with "
#  "text 'Treyes Albarrac��N'\n")

# %%
# !pwd
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# pwd: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
